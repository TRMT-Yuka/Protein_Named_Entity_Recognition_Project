# %%
# !pip install mygene
# !pip install biothings_client

# %%
from biothings_client import get_client
mg = get_client("gene")

# %%
# キーワードの検索結果件数と一覧

# mg.query(keyword)

# {'took': 12,
#  'total': 2307,
#  'max_score': 394.02466,
#  'hits': [{'_id': '10845',
#    '_score': 394.02466,
#    'entrezgene': '10845',
#    'name': 'caseinolytic mitochondrial matrix peptidase chaperone subunit X',
#    'symbol': 'CLPX',
#    'taxid': 9606},
#   {'_id': '270166',.....

# %% [markdown]
# # gene_infoの各項目

# %%
gene_info = mg.getgene("ENSG00000141570")

# %%
for key,value in gene_info.items():
    print(key,":",type(value))
# Out:
# HGNC : <class 'str'>
# MIM : <class 'str'>
# _id : <class 'str'>
# _version : <class 'int'>
# accession : <class 'dict'>
# alias : <class 'list'>
# ensembl : <class 'dict'>
# entrezgene : <class 'str'>
# exac : <class 'dict'>
# exons : <class 'list'>
# exons_hg19 : <class 'list'>
# generif : <class 'list'>
# genomic_pos : <class 'dict'>
# genomic_pos_hg19 : <class 'list'>
# go : <class 'dict'>
# homologene : <class 'dict'>
# interpro : <class 'list'>
# ipi : <class 'list'>
# map_location : <class 'str'>
# name : <class 'str'>
# other_names : <class 'list'>
# pantherdb : <class 'dict'>
# pathway : <class 'dict'>
# pdb : <class 'list'>
# pfam : <class 'list'>
# pharmgkb : <class 'str'>
# pharos : <class 'dict'>
# prosite : <class 'str'>
# reagent : <class 'dict'>
# refseq : <class 'dict'>
# reporter : <class 'dict'>
# retired : <class 'list'>
# symbol : <class 'str'>
# taxid : <class 'int'>
# type_of_gene : <class 'str'>
# umls : <class 'dict'>
# unigene : <class 'str'>
# uniprot : <class 'dict'>
# wikipedia : <class 'dict'>

# %%
gene_info["ensembl"]
# {'gene': 'ENSG00000141570',
#  'protein': ['ENSP00000269385', 'ENSP00000405058', 'ENSP00000408753'],
#  'transcript': ['ENST00000269385',....],
#  'translation': [{'protein': 'ENSP00000269385', 'rna': 'ENST00000269385'},....],
#  'type_of_gene': 'protein_coding'}
gene_info["ensembl"]["gene"]
# 遺伝子に関する情報
gene_info["ensembl"]["protein"]
# 生成されるタンパク質種類

gene_info["entrezgene"]
#人間とか犬とか生物のカテゴリを表すID

gene_info["pdb"]
#PDB IDは重複しない４文字のコードで、タンパク質
#データバンクの各エントリーに割り振られます。
#最初の文字は必ず1から9までの数字で、残りの３文字は
#アルファベットまたは数字が使われます。

gene_info["generif"]
# 文献と出現テキストのリスト
# [{'pubmed': 17332741,'text': 'CBX8 is an essenti...'}]

gene_info["name"]
#正式名称

gene_info["other_names"]
# 正式名称表記ゆれ

gene_info["pdb"]
#タンパク質固有ID
# ['2N4Q', '3I91', '5EQ0']
# Out:
# ['2N4Q', '3I91', '5EQ0']

# %% [markdown]
# # データの読み込み

# %%
# Out:
# dict

# %%
import pandas as pd
data = pd.read_csv('data_summary/PROT/lll_bioc_prot.csv').values.tolist()

# %%
import copy
new_data = copy.deepcopy(data)

# %%
new_data[0:15]
# Out:
# [['ClpX', 6],
#  ['ComK', 10],
#  ['CsbB', 2],
#  ['CtsR', 6],
#  ['DnaK', 8],
#  ['E sigma E', 6],
#  ['EsigmaF', 8],
#  ['FlgM', 13],
#  ['FtsZ', 25],
#  ['GerE', 210],
#  ['KatX', 8],
#  ['KinC', 2],
#  ['KinD', 2],
#  ['PBP4*', 7],
#  ['PhoP~P', 3]]

# %%
# import urllib

# %%
label = ["protein","appearances","hits","max_score_hits"]

# %%
from biothings_client import get_client
import copy
import json
import pandas as pd
import csv
#当然ながらネット接続時でないとエラーになる

# 生成先のディレクトリは手動作成
def get_Query(filename):
    mg = get_client("gene")
    data = pd.read_csv('data_summary/PROT/'+filename+'_prot.csv').values.tolist()
    new_data = copy.deepcopy(data)
    
    for i in range(len(new_data)):
        keyword = new_data[i][0]
        max_score_hit = []

        try:
            max_score_hit = []
            result = mg.query(keyword)
            wf = open('data_query/QUERY/all/'+filename+'/'+str(i)+'_'+keyword+'.json','w',encoding='UTF-8',newline='\n')
            wf.write(json.dumps(result))
            wf.close()

            search_results = result["total"]
            max_score = result["max_score"]

            if search_results != 0:
                wf = open('data_query/QUERY/best_score/'+filename+'/'+str(i)+'_'+keyword+'.json','w',encoding='UTF-8',newline='\n')
                for hit in result["hits"]:
                    if hit["_score"] == max_score:
                        wf.write(json.dumps(hit))
                        wf.write("\n")
                        max_score_hit.append(hit)
                wf.close()
            print(i,"/",len(new_data)-1,"   ",keyword,"=>",search_results,"(max_hits",len(max_score_hit),")")

            

        except:
            print(i,"/",len(new_data),"   HTTPError")
            search_results = -1

        new_data[i].append(search_results)
        new_data[i].append(len(max_score_hit))

    label = ["protein","appearances","hits","max_score_hits"]
    new_data.insert(0, label)
    with open("data_query/PROT/"+filename+"_result.csv", "w") as f:
        writer = csv.writer(f, lineterminator='\n')#ここ大事
        writer.writerows(new_data)

# %%
import os
files = os.listdir("data_original")

val_name = []
for a_file in files:
    with open("data_original/"+a_file, 'r') as fp:
        dynmc_name = a_file.replace(".xml","")
        val_name.append(dynmc_name)

# %%
val_name
# Out:
# ['aimed_bioc', 'bioinfer_bioc', 'hprd50_bioc', 'iepa_bioc', 'lll_bioc']

# %%
for filename in val_name[:1]:
    print(filename)
    get_Query(filename)
# Out:
# aimed_bioc
# 0 / 1136     .CDC37 => 1670 (max_hits 10 )
# 1 / 1136     120-kDa phosphoprotein => 0 (max_hits 0 )
# 2 / 1136     14-3-3 beta => 1413 (max_hits 1 )
# 3 / 1136     14-3-3 zeta => 1710 (max_hits 2 )
# 4 / 1136     5 E1B => 1040 (max_hits 10 )
# 5 / 1136     53BP2 => 2 (max_hits 1 )
# 6 / 1136     56Lyn => 0 (max_hits 0 )
# 7 / 1136     80K-H => 448 (max_hits 1 )
# 8 / 1136     87K postsynaptic protein => 0 (max_hits 0 )
# 9 / 1136     A beta => 23648 (max_hits 1 )
# 10 / 1136     A kinase anchoring protein => 5679 (max_hits 1 )
# 11 / 1136     AADC => 65 (max_hits 10 )
# 12 / 1136     ABL-SH3 => 22 (max_hits 1 )
# 13 / 1136     ABP-280 => 7 (max_hits 1 )
# 14 / 1136     ADA => 974 (max_hits 1 )
# 15 / 1136     ADA-1 => 27 (max_hits 2 )
# 16 / 1136     AKAP75 => 2 (max_hits 1 )
# 17 / 1136     AKAP79 => 2 (max_hits 1 )
# 18 / 1136     AP-1 => 21456 (max_hits 7 )
# 19 / 1136     AP1 => 217 (max_hits 10 )
# 20 / 1136     APO-1 => 280 (max_hits 1 )
# 21 / 1136     AT mutated => 31 (max_hits 1 )
# 22 / 1136     ATF => 6673 (max_hits 1 )
# 23 / 1136     ATM => 3327 (max_hits 1 )
# 24 / 1136     Abeta => 249 (max_hits 1 )
# 25 / 1136     Abeta peptide => 5 (max_hits 1 )
# 26 / 1136     ActR-II => 6 (max_hits 1 )
# 27 / 1136     ActRII => 4 (max_hits 1 )
# 28 / 1136     Activin A => 3189 (max_hits 1 )
# 29 / 1136     Apo-1 => 280 (max_hits 1 )
# 30 / 1136     B beta chain of fibrinogen => 372 (max_hits 10 )
# 31 / 1136     B cell activation protein => 997 (max_hits 10 )
# 32 / 1136     B-50 => 473 (max_hits 2 )
# 33 / 1136     B42 => 2 (max_hits 2 )
# 34 / 1136     B61 => 8 (max_hits 1 )
# 35 / 1136     BAG => 6103 (max_hits 2 )
# 36 / 1136     BAG-1 => 1417 (max_hits 1 )
# 37 / 1136     BB isoform of human recombinant platelet-derived growth factor => 2 (max_hits 2 )
# 38 / 1136     BDNF => 1157 (max_hits 1 )
# 39 / 1136     BMP receptor IA => 10 (max_hits 2 )
# 40 / 1136     BMP receptor IA extracellular domain => 2 (max_hits 2 )
# 41 / 1136     BMP receptor type IB => 10 (max_hits 2 )
# 42 / 1136     BMP type II receptor => 37 (max_hits 1 )
# 43 / 1136     BMP-2 => 1851 (max_hits 1 )
# 44 / 1136     BMP-4 => 36 (max_hits 1 )
# 45 / 1136     BMP-6 => 15 (max_hits 1 )
# 46 / 1136     BMP-7 => 18 (max_hits 1 )
# 47 / 1136     BMPR-IA => 8 (max_hits 1 )
# 48 / 1136     BMPR-II => 11 (max_hits 1 )
# 49 / 1136     BMPRIB => 2 (max_hits 1 )
# 50 / 1136     BR-I => 17 (max_hits 1 )
# 51 / 1136     BR-II => 6 (max_hits 1 )
# 52 / 1136     BR-Ia => 1 (max_hits 1 )
# 53 / 1136     BR-Ib => 0 (max_hits 0 )
# 54 / 1136     BRIA => 0 (max_hits 0 )
# 55 / 1136     BRIAec => 0 (max_hits 0 )
# 56 / 1136     Bax => 4605 (max_hits 1 )
# 57 / 1136     Bcl-2 => 7648 (max_hits 2 )
# 58 / 1136     Bcl-2-binding protein => 123 (max_hits 1 )
# 59 / 1136     Bcl-X => 38 (max_hits 1 )
# 60 / 1136     Bcl-X-L => 16 (max_hits 1 )
# 61 / 1136     Bcl-X-S => 3 (max_hits 1 )
# 62 / 1136     Bcl-x(L) => 16 (max_hits 1 )
# 63 / 1136     Bcl-xL => 29 (max_hits 2 )
# 64 / 1136     Blimp-1 => 24 (max_hits 3 )
# 65 / 1136     Bone morphogenetic protein-2 => 2448 (max_hits 1 )
# 66 / 1136     Bp50 => 3 (max_hits 1 )
# 67 / 1136     C3 => 9980 (max_hits 1 )
# 68 / 1136     C4 => 9701 (max_hits 10 )
# 69 / 1136     C5 => 6430 (max_hits 1 )
# 70 / 1136     C8 => 2538 (max_hits 3 )
# 71 / 1136     C9 => 2216 (max_hits 1 )
# 72 / 1136     CAP-60 => 2 (max_hits 1 )
# 73 / 1136     CBP => 3241 (max_hits 10 )
# 74 / 1136     CC CKR1 => 6 (max_hits 4 )
# 75 / 1136     CC CKR3 => 10 (max_hits 4 )
# 76 / 1136     CC chemokine liver-expressed chemokine => 5 (max_hits 4 )
# 77 / 1136     CC chemokine receptor 3 => 1052 (max_hits 1 )
# 78 / 1136     CCG1 => 23 (max_hits 2 )
# 79 / 1136     CCKB => 78 (max_hits 10 )
# 80 / 1136     CCKB G protein-coupled receptor => 269 (max_hits 1 )
# 81 / 1136     CCKB receptor => 78 (max_hits 1 )
# 82 / 1136     CCL16 => 176 (max_hits 1 )
# 83 / 1136     CCR-5 => 23 (max_hits 3 )
# 84 / 1136     CCR1 => 343 (max_hits 1 )
# 85 / 1136     CCR2 => 283 (max_hits 1 )
# 86 / 1136     CCR3 => 759 (max_hits 1 )
# 87 / 1136     CCR5 => 158 (max_hits 1 )
# 88 / 1136     CCR8 => 236 (max_hits 1 )
# 89 / 1136     CD14 => 318 (max_hits 1 )
# 90 / 1136     CD16 => 12 (max_hits 1 )
# 91 / 1136     CD26 => 25 (max_hits 2 )
# 92 / 1136     CD3 => 1665 (max_hits 3 )
# 93 / 1136     CD30 => 9 (max_hits 1 )
# 94 / 1136     CD30 ligand => 4 (max_hits 1 )
# 95 / 1136     CD30L => 6 (max_hits 1 )
# 96 / 1136     CD34 => 481 (max_hits 1 )
# 97 / 1136     CD4 => 1026 (max_hits 1 )
# 98 / 1136     CD40 => 1013 (max_hits 1 )
# 99 / 1136     CD40 ligand => 991 (max_hits 1 )
# 100 / 1136     CD44 => 566 (max_hits 1 )
# 101 / 1136     CD45 => 32 (max_hits 4 )
# 102 / 1136     CD5 => 930 (max_hits 1 )
# 103 / 1136     CD72 => 457 (max_hits 1 )
# 104 / 1136     CD8 => 1156 (max_hits 1 )
# 105 / 1136     CD8alpha => 3 (max_hits 1 )
# 106 / 1136     CD9 => 1247 (max_hits 1 )
# 107 / 1136     CD95 => 43 (max_hits 1 )
# 108 / 1136     CD95 ligand => 12 (max_hits 1 )
# 109 / 1136     CD95L => 30 (max_hits 1 )
# 110 / 1136     CDC2 => 1362 (max_hits 10 )
# 111 / 1136     CDC2-HS => 41 (max_hits 1 )
# 112 / 1136     CDC28 => 1039 (max_hits 10 )
# 113 / 1136     CDC37 => 1670 (max_hits 1 )
# 114 / 1136     CDK2 => 1157 (max_hits 1 )
# 115 / 1136     CDK4 => 908 (max_hits 1 )
# 116 / 1136     CDK6 => 507 (max_hits 1 )
# 117 / 1136     CIP1 => 556 (max_hits 10 )
# 118 / 1136     CNTF => 439 (max_hits 1 )
# 119 / 1136     CNTFR alpha => 495 (max_hits 1 )
# 120 / 1136     COX-2 => 985 (max_hits 1 )
# 121 / 1136     CREB => 4361 (max_hits 10 )
# 122 / 1136     CREB-binding protein => 1299 (max_hits 1 )
# 123 / 1136     CRP3 => 17 (max_hits 2 )
# 124 / 1136     CSA => 693 (max_hits 3 )
# 125 / 1136     CSB => 134 (max_hits 5 )
# 126 / 1136     CSB protein => 113 (max_hits 5 )
# 127 / 1136     CTF => 35 (max_hits 2 )
# 128 / 1136     CTF-1 => 18 (max_hits 1 )
# 129 / 1136     CTLA-4 => 23 (max_hits 1 )
# 130 / 1136     CXCR-4 => 18 (max_hits 1 )
# 131 / 1136     CXCR1 => 160 (max_hits 1 )
# 132 / 1136     CXCR2 => 293 (max_hits 1 )
# 133 / 1136     CXCR4 => 452 (max_hits 1 )
# 134 / 1136     CaM => 2293 (max_hits 10 )
# 135 / 1136     CaN => 22518 (max_hits 1 )
# 136 / 1136     CaR => 117 (max_hits 4 )
# 137 / 1136     Calnexin => 1786 (max_hits 1 )
# 138 / 1136     Calreticulin => 2688 (max_hits 1 )
# 139 / 1136     Cdc2 => 1362 (max_hits 10 )
# 140 / 1136     Cdc25 => 434 (max_hits 10 )
# 141 / 1136     Cdc25 phosphatase => 341 (max_hits 10 )
# 142 / 1136     Cdi1 => 1 (max_hits 1 )
# 143 / 1136     Cdk2 => 1157 (max_hits 1 )
# 144 / 1136     Cdk3 => 342 (max_hits 1 )
# 145 / 1136     Cdk4 => 908 (max_hits 1 )
# 146 / 1136     Cip1 => 556 (max_hits 10 )
# 147 / 1136     Cockayne syndrome group B (CSB) protein => 33 (max_hits 1 )
# 148 / 1136     Col II => 13 (max_hits 2 )
# 149 / 1136     Col III => 13 (max_hits 2 )
# 150 / 1136     Crk => 1657 (max_hits 1 )
# 151 / 1136     Crk-L => 6 (max_hits 1 )
# 152 / 1136     CrmA => 8 (max_hits 1 )
# 153 / 1136     Cyclin E => 1176 (max_hits 10 )
# 154 / 1136     DAF-4 => 25 (max_hits 1 )
# 155 / 1136     DNA polymerase delta => 7641 (max_hits 2 )
# 156 / 1136     DP1 => 237 (max_hits 6 )
# 157 / 1136     DPC4 => 9 (max_hits 1 )
# 158 / 1136     DPI => 5 (max_hits 1 )
# 159 / 1136     DRP => 68 (max_hits 3 )
# 160 / 1136     DcR3 => 8 (max_hits 1 )
# 161 / 1136     Desmoplakin => 870 (max_hits 4 )
# 162 / 1136     Duffy antigen => 29 (max_hits 1 )
# 163 / 1136     Dystrophin => 2735 (max_hits 1 )
# 164 / 1136     E-cadherin => 107 (max_hits 1 )
# 165 / 1136     E12 => 52 (max_hits 3 )
# 166 / 1136     E1A => 2559 (max_hits 10 )
# 167 / 1136     E1B => 3272 (max_hits 10 )
# 168 / 1136     E2A => 635 (max_hits 8 )
# 169 / 1136     E2F => 5705 (max_hits 6 )
# 170 / 1136     E2F-1 => 629 (max_hits 3 )
# 171 / 1136     E2F1 => 759 (max_hits 1 )
# 172 / 1136     E2F4 => 826 (max_hits 1 )
# 173 / 1136     E47 => 30 (max_hits 1 )
# 174 / 1136     E7 => 313 (max_hits 10 )
# 175 / 1136     EBP => 1196 (max_hits 1 )
# 176 / 1136     EBP delta => 431 (max_hits 1 )
# 177 / 1136     ECK => 6 (max_hits 1 )
# 178 / 1136     ECK receptor protein-tyrosine kinase => 5 (max_hits 2 )
# 179 / 1136     EGF => 25037 (max_hits 1 )
# 180 / 1136     EGFR => 790 (max_hits 1 )
# 181 / 1136     EMP1 => 656 (max_hits 1 )
# 182 / 1136     EPO => 331 (max_hits 1 )
# 183 / 1136     EPO binding protein => 242 (max_hits 1 )
# 184 / 1136     EPO mimetic peptide => 240 (max_hits 1 )
# 185 / 1136     EPO-binding protein => 2 (max_hits 1 )
# 186 / 1136     EPO-mimetic peptide => 0 (max_hits 0 )
# 187 / 1136     EPOR => 390 (max_hits 1 )
# 188 / 1136     ER => 29922 (max_hits 6 )
# 189 / 1136     ET(A) => 512 (max_hits 1 )
# 190 / 1136     ET(A) receptor => 88 (max_hits 1 )
# 191 / 1136     ET(B) => 83 (max_hits 1 )
# 192 / 1136     ET(B) receptor => 30 (max_hits 1 )
# 193 / 1136     ET- I => 93 (max_hits 10 )
# 194 / 1136     ET-1 => 703 (max_hits 1 )
# 195 / 1136     ET-3 => 149 (max_hits 1 )
# 196 / 1136     Elf-1 => 685 (max_hits 1 )
# 197 / 1136     Endothelin-1 => 3457 (max_hits 1 )
# 198 / 1136     Eotaxin-3 => 14 (max_hits 1 )
# 199 / 1136     ErbB-1 => 948 (max_hits 1 )
# 200 / 1136     ErbB-2 => 486 (max_hits 7 )
# 201 / 1136     ErbB-3 => 835 (max_hits 10 )
# 202 / 1136     ErbB-4 => 822 (max_hits 10 )
# 203 / 1136     ErbB2 => 2210 (max_hits 1 )
# 204 / 1136     ErbB3 => 440 (max_hits 1 )
# 205 / 1136     ErbB4 => 621 (max_hits 1 )
# 206 / 1136     Estrogen Receptor => 6212 (max_hits 1 )
# 207 / 1136     Ets => 14806 (max_hits 5 )
# 208 / 1136     F1 => 10777 (max_hits 1 )
# 209 / 1136     FADD => 1273 (max_hits 1 )
# 210 / 1136     FD5 => 77 (max_hits 10 )
# 211 / 1136     FD8 => 0 (max_hits 0 )
# 212 / 1136     FGF-1 => 818 (max_hits 4 )
# 213 / 1136     FGF-2 => 588 (max_hits 4 )
# 214 / 1136     FGF-7 => 62 (max_hits 1 )
# 215 / 1136     FGF1 => 735 (max_hits 1 )
# 216 / 1136     FGF10 => 407 (max_hits 1 )
# 217 / 1136     FGF2 => 498 (max_hits 1 )
# 218 / 1136     FGF6 => 405 (max_hits 1 )
# 219 / 1136     FGF7 => 500 (max_hits 1 )
# 220 / 1136     FGF9 => 454 (max_hits 1 )
# 221 / 1136     FGFG3 => 0 (max_hits 0 )
# 222 / 1136     FGFR1 => 2303 (max_hits 1 )
# 223 / 1136     FGFR2 => 977 (max_hits 1 )
# 224 / 1136     FGFR2 IIIb => 478 (max_hits 1 )
# 225 / 1136     FGFR2b => 51 (max_hits 1 )
# 226 / 1136     FGFR2c => 63 (max_hits 1 )
# 227 / 1136     FGFR3 => 749 (max_hits 1 )
# 228 / 1136     FGFR3 IIIb => 480 (max_hits 1 )
# 229 / 1136     FGFR3 IIIc => 480 (max_hits 1 )
# 230 / 1136     FGFR4 => 738 (max_hits 1 )
# 231 / 1136     FKBP12 => 676 (max_hits 8 )
# 232 / 1136     FKBP12-rapamycin-associated protein => 41 (max_hits 4 )
# 233 / 1136     FLICE => 18 (max_hits 1 )
# 234 / 1136     FLT-1 => 23 (max_hits 1 )
# 235 / 1136     FRAP => 31 (max_hits 3 )
# 236 / 1136     FXIII => 0 (max_hits 0 )
# 237 / 1136     Fas => 6490 (max_hits 1 )
# 238 / 1136     Fas ligand => 904 (max_hits 1 )
# 239 / 1136     FasL => 41 (max_hits 1 )
# 240 / 1136     Flk-1 => 18 (max_hits 1 )
# 241 / 1136     Flk1 => 14 (max_hits 2 )
# 242 / 1136     Flt1 => 496 (max_hits 1 )
# 243 / 1136     Flt4 => 496 (max_hits 1 )
# 244 / 1136     Fos => 2643 (max_hits 1 )
# 245 / 1136     FosB => 884 (max_hits 1 )
# 246 / 1136     Fra1 => 74 (max_hits 5 )
# 247 / 1136     Fra2 => 12 (max_hits 2 )
# 248 / 1136     G alpha beta gamma => 738 (max_hits 7 )
# 249 / 1136     G alpha i2 => 525 (max_hits 2 )
# 250 / 1136     G beta 2 => 3190 (max_hits 10 )
# 251 / 1136     G beta 2 subunit => 2233 (max_hits 10 )
# 252 / 1136     G beta gamma => 766 (max_hits 7 )
# 253 / 1136     G cathepsin => 646 (max_hits 10 )
# 254 / 1136     G-protein beta gamma => 556 (max_hits 7 )
# 255 / 1136     GAP-334 => 0 (max_hits 0 )
# 256 / 1136     GAP-43 => 128 (max_hits 1 )
# 257 / 1136     GCH => 13 (max_hits 3 )
# 258 / 1136     GFAp => 386 (max_hits 1 )
# 259 / 1136     GITR => 8 (max_hits 1 )
# 260 / 1136     GITR ligand => 2 (max_hits 1 )
# 261 / 1136     GM-CSF => 262 (max_hits 1 )
# 262 / 1136     GM-CSF-R => 243 (max_hits 1 )
# 263 / 1136     GRB2 => 8365 (max_hits 1 )
# 264 / 1136     GS => 3018 (max_hits 2 )
# 265 / 1136     GSK-3 => 423 (max_hits 4 )
# 266 / 1136     GT155 => 0 (max_hits 0 )
# 267 / 1136     GTP cyclohydrolase I => 2339 (max_hits 10 )
# 268 / 1136     GTPase-activating protein => 67382 (max_hits 1 )
# 269 / 1136     Gas6 => 500 (max_hits 1 )
# 270 / 1136     Gastrin => 2213 (max_hits 1 )
# 271 / 1136     Glut 1 => 1055 (max_hits 1 )
# 272 / 1136     Granulysin => 101 (max_hits 1 )
# 273 / 1136     Grb2 => 8365 (max_hits 1 )
# 274 / 1136     Grb7 => 459 (max_hits 1 )
# 275 / 1136     H-Ras => 535 (max_hits 1 )
# 276 / 1136     H-ras => 535 (max_hits 1 )
# 277 / 1136     HBx => 9 (max_hits 1 )
# 278 / 1136     HCC-4 => 5 (max_hits 1 )
# 279 / 1136     HFE => 205 (max_hits 1 )
# 280 / 1136     HLA-E => 68 (max_hits 1 )
# 281 / 1136     HLH462 => 1 (max_hits 1 )
# 282 / 1137    HTTPError
# 283 / 1136     HOX11 => 314 (max_hits 1 )
# 284 / 1136     HS1 => 315 (max_hits 5 )
# 285 / 1136     HSP27 => 39 (max_hits 3 )
# 286 / 1136     HSP90 => 3992 (max_hits 10 )
# 287 / 1136     HVEM => 8 (max_hits 1 )
# 288 / 1136     Ha-Ras => 42 (max_hits 1 )
# 289 / 1136     Hepatitis B virus X protei => 65 (max_hits 10 )
# 290 / 1136     Hepatitis B virus X protein => 141 (max_hits 10 )
# 291 / 1136     Hip => 468 (max_hits 4 )
# 292 / 1136     Hox11 => 314 (max_hits 1 )
# 293 / 1136     Ht 21 => 1022 (max_hits 1 )
# 294 / 1136     Ht 31 => 995 (max_hits 1 )
# 295 / 1136     I-eotaxin => 2 (max_hits 1 )
# 296 / 1136     I309 => 0 (max_hits 0 )
# 297 / 1136     ICE => 1350 (max_hits 1 )
# 298 / 1136     IFN-alpha => 298 (max_hits 1 )
# 299 / 1136     IFN-gamma => 123 (max_hits 2 )
# 300 / 1136     IFN-gamma R alpha => 72 (max_hits 8 )
# 301 / 1136     IFN-gamma R beta => 401 (max_hits 10 )
# 302 / 1136     IFN-gamma SC1 => 2 (max_hits 2 )
# 303 / 1136     IFN-gamma receptor => 36 (max_hits 1 )
# 304 / 1136     IFN-gamma receptor alpha chain => 13 (max_hits 1 )
# 305 / 1136     IFNR => 1 (max_hits 1 )
# 306 / 1136     IFNalpha => 4 (max_hits 1 )
# 307 / 1136     IFNalpha2 => 0 (max_hits 0 )
# 308 / 1136     IGF-1 => 1021 (max_hits 4 )
# 309 / 1136     IGF-1 receptor => 495 (max_hits 1 )
# 310 / 1136     IGF-1R => 7 (max_hits 1 )
# 311 / 1136     IGF-1R beta => 343 (max_hits 10 )
# 312 / 1136     IGF-I => 159 (max_hits 10 )
# 313 / 1136     IGF-IR => 5 (max_hits 1 )
# 314 / 1136     IGIF => 7 (max_hits 1 )
# 315 / 1136     IL 1ra => 15 (max_hits 1 )
# 316 / 1136     IL-1 => 1010 (max_hits 10 )
# 317 / 1136     IL-1 receptor => 780 (max_hits 1 )
# 318 / 1136     IL-1 receptor-associated kinase => 16 (max_hits 1 )
# 319 / 1136     IL-1-receptor => 779 (max_hits 10 )
# 320 / 1136     IL-1-receptor antagonist => 33 (max_hits 10 )
# 321 / 1136     IL-10 => 112 (max_hits 1 )
# 322 / 1136     IL-10 receptor => 49 (max_hits 1 )
# 323 / 1136     IL-10R => 4 (max_hits 1 )
# 324 / 1136     IL-11 => 27 (max_hits 1 )
# 325 / 1136     IL-13 => 74 (max_hits 1 )
# 326 / 1136     IL-13 receptor => 46 (max_hits 1 )
# 327 / 1136     IL-13R => 6 (max_hits 1 )
# 328 / 1136     IL-13Ralpha => 0 (max_hits 0 )
# 329 / 1136     IL-15 => 53 (max_hits 1 )
# 330 / 1136     IL-1RI => 1 (max_hits 1 )
# 331 / 1136     IL-1alpha => 3 (max_hits 1 )
# 332 / 1136     IL-1beta => 15 (max_hits 1 )
# 333 / 1136     IL-1ra => 15 (max_hits 1 )
# 334 / 1136     IL-2 => 303 (max_hits 8 )
# 335 / 1136     IL-2 receptor => 176 (max_hits 1 )
# 336 / 1136     IL-2 receptor beta => 424 (max_hits 1 )
# 337 / 1136     IL-2 receptor gamma => 42 (max_hits 1 )
# 338 / 1136     IL-2R beta => 348 (max_hits 10 )
# 339 / 1136     IL-3 => 107 (max_hits 1 )
# 340 / 1136     IL-4 => 132 (max_hits 3 )
# 341 / 1136     IL-4 receptor => 68 (max_hits 1 )
# 342 / 1136     IL-4R => 5 (max_hits 1 )
# 343 / 1136     IL-4Ralpha => 2 (max_hits 1 )
# 344 / 1136     IL-5 => 68 (max_hits 3 )
# 345 / 1136     IL-5 receptor => 50 (max_hits 1 )
# 346 / 1136     IL-6 => 273 (max_hits 2 )
# 347 / 1136     IL-6 receptor => 90 (max_hits 1 )
# 348 / 1136     IL-6.receptor => 87 (max_hits 1 )
# 349 / 1136     IL-6D => 0 (max_hits 0 )
# 350 / 1136     IL-6M => 0 (max_hits 0 )
# 351 / 1136     IL-6R => 12 (max_hits 1 )
# 352 / 1136     IL-6R alpha => 20 (max_hits 8 )
# 353 / 1136     IL-7 => 45 (max_hits 1 )
# 354 / 1136     IL-7 receptor => 30 (max_hits 2 )
# 355 / 1136     IL-7R => 7 (max_hits 1 )
# 356 / 1136     IL-8 => 92 (max_hits 3 )
# 357 / 1136     IL-8 receptor subtypes A => 39 (max_hits 1 )
# 358 / 1136     IL-9 => 43 (max_hits 1 )
# 359 / 1136     IL1R => 18 (max_hits 1 )
# 360 / 1136     IL1RA => 8 (max_hits 1 )
# 361 / 1136     INK4a => 6 (max_hits 1 )
# 362 / 1136     INK4b => 9 (max_hits 1 )
# 363 / 1136     INK4d => 6 (max_hits 1 )
# 364 / 1136     IR => 47 (max_hits 2 )
# 365 / 1136     IR beta => 348 (max_hits 2 )
# 366 / 1136     IRAK => 24 (max_hits 1 )
# 367 / 1136     IRF4 => 403 (max_hits 1 )
# 368 / 1136     IRS-1 => 330 (max_hits 1 )
# 369 / 1136     IRS1 => 414 (max_hits 1 )
# 370 / 1136     ITAM => 648 (max_hits 1 )
# 371 / 1136     ITF-2 => 4 (max_hits 1 )
# 372 / 1136     ITF-2a => 1 (max_hits 1 )
# 373 / 1136     ITF-2b => 1 (max_hits 1 )
# 374 / 1136     Id3 => 452 (max_hits 1 )
# 375 / 1136     Inhibin => 3188 (max_hits 1 )
# 376 / 1136     Inr-binding protein => 0 (max_hits 0 )
# 377 / 1136     Insulin receptor substrate 1 => 2162 (max_hits 1 )
# 378 / 1136     Interferon-alpha => 5734 (max_hits 10 )
# 379 / 1136     Interferon-gamma => 4066 (max_hits 1 )
# 380 / 1136     Interleukin-1 => 14051 (max_hits 2 )
# 381 / 1136     Interleukin-10 => 2518 (max_hits 1 )
# 382 / 1136     Interleukin-13 => 1556 (max_hits 1 )
# 383 / 1136     Interleukin-2 => 7628 (max_hits 1 )
# 384 / 1136     JAK2 => 878 (max_hits 1 )
# 385 / 1136     JAK2 kinase => 874 (max_hits 1 )
# 386 / 1136     JNK1 => 893 (max_hits 1 )
# 387 / 1136     Jak => 97 (max_hits 1 )
# 388 / 1136     Jak1 => 659 (max_hits 1 )
# 389 / 1136     Jak3 => 486 (max_hits 1 )
# 390 / 1136     Jif-1 => 1 (max_hits 1 )
# 391 / 1136     Jun => 5927 (max_hits 1 )
# 392 / 1136     Jun-interacting factor (Jif)-1 => 0 (max_hits 0 )
# 393 / 1136     K-ras => 57 (max_hits 1 )
# 394 / 1136     K1 => 916 (max_hits 3 )
# 395 / 1136     K2 => 1175 (max_hits 4 )
# 396 / 1136     K5 => 31 (max_hits 2 )
# 397 / 1136     K6 => 210 (max_hits 1 )
# 398 / 1136     KDR => 923 (max_hits 1 )
# 399 / 1136     KGFR => 4 (max_hits 1 )
# 400 / 1136     KIP1 => 130 (max_hits 8 )
# 401 / 1136     KIP2 => 30 (max_hits 8 )
# 402 / 1136     LEC => 344 (max_hits 1 )
# 403 / 1136     LEU2 => 84 (max_hits 10 )
# 404 / 1136     LIF => 838 (max_hits 1 )
# 405 / 1136     LIF receptor => 825 (max_hits 1 )
# 406 / 1136     LIFR => 359 (max_hits 1 )
# 407 / 1136     LIGHT => 59565 (max_hits 2 )
# 408 / 1136     LMC => 2 (max_hits 1 )
# 409 / 1136     LPR => 76 (max_hits 1 )
# 410 / 1136     LT-alpha => 20 (max_hits 1 )
# 411 / 1136     LT-beta => 27 (max_hits 1 )
# 412 / 1136     LTbetaR => 2 (max_hits 1 )
# 413 / 1136     LexA => 1457 (max_hits 10 )
# 414 / 1136     Liver-expressed chemokine => 2 (max_hits 1 )
# 415 / 1136     Ln-5 => 0 (max_hits 0 )
# 416 / 1136     Ln-5 gamma2 => 0 (max_hits 0 )
# 417 / 1136     Lyn => 1000 (max_hits 1 )
# 418 / 1136     MACH => 5 (max_hits 1 )
# 419 / 1136     MAP kinase => 11448 (max_hits 10 )
# 420 / 1136     MAP kinase kinase => 11448 (max_hits 10 )
# 421 / 1136     MCP-1 => 65 (max_hits 3 )
# 422 / 1136     MCP-2 => 38 (max_hits 1 )
# 423 / 1136     MCP-3 => 16 (max_hits 1 )
# 424 / 1136     MCP-4 => 11 (max_hits 1 )
# 425 / 1136     MDM2 => 1915 (max_hits 1 )
# 426 / 1136     MEK-1 => 64 (max_hits 3 )
# 427 / 1136     MIP => 797 (max_hits 1 )
# 428 / 1136     MIP-1 alpha => 57 (max_hits 4 )
# 429 / 1136     MIP-1 beta => 374 (max_hits 4 )
# 430 / 1136     MIP-1alpha => 14 (max_hits 1 )
# 431 / 1136     MIP-1beta => 5 (max_hits 1 )
# 432 / 1136     MMP-1 => 362 (max_hits 4 )
# 433 / 1136     MMP2 => 514 (max_hits 1 )
# 434 / 1136     MORT => 2 (max_hits 1 )
# 435 / 1136     MPIF-2 => 2 (max_hits 1 )
# 436 / 1136     Max => 5993 (max_hits 1 )
# 437 / 1136     Mcl-1 => 644 (max_hits 3 )
# 438 / 1136     Mxi1 => 509 (max_hits 1 )
# 439 / 1136     Myc => 9596 (max_hits 1 )
# 440 / 1136     MyoD => 1777 (max_hits 10 )
# 441 / 1136     Myogenin => 521 (max_hits 1 )
# 442 / 1136     NADPH oxidase => 3995 (max_hits 4 )
# 443 / 1136     NCC-4 => 3 (max_hits 1 )
# 444 / 1136     NF-IL6 beta => 347 (max_hits 10 )
# 445 / 1136     NF-kappa B => 8484 (max_hits 10 )
# 446 / 1136     NF-kappaB => 507 (max_hits 1 )
# 447 / 1136     NF-kappaB-inducing kinase => 2 (max_hits 1 )
# 448 / 1136     NFL => 11 (max_hits 1 )
# 449 / 1136     NGF => 547 (max_hits 1 )
# 450 / 1136     NGF-receptor => 118 (max_hits 1 )
# 451 / 1136     NIK => 699 (max_hits 1 )
# 452 / 1136     NMDA receptor => 7164 (max_hits 1 )
# 453 / 1136     NR1 => 48 (max_hits 3 )
# 454 / 1136     NR2B => 9 (max_hits 1 )
# 455 / 1136     NRAMP1 => 151 (max_hits 10 )
# 456 / 1136     Nck => 5240 (max_hits 4 )
# 457 / 1136     Nerve growth factor => 2289 (max_hits 1 )
# 458 / 1136     Nucleobindin => 1478 (max_hits 2 )
# 459 / 1136     OP-1 => 11 (max_hits 1 )
# 460 / 1136     Oct1 => 65 (max_hits 10 )
# 461 / 1136     Oct2 => 85 (max_hits 10 )
# 462 / 1136     P13-K => 0 (max_hits 0 )
# 463 / 1136     P150 => 286 (max_hits 2 )
# 464 / 1136     P60 => 3617 (max_hits 6 )
# 465 / 1136     PAI-1 => 51 (max_hits 3 )
# 466 / 1136     PARP => 279 (max_hits 6 )
# 467 / 1136     PCNA => 2306 (max_hits 1 )
# 468 / 1136     PDGF => 387 (max_hits 1 )
# 469 / 1136     PDGF A => 159 (max_hits 1 )
# 470 / 1136     PDGF alpha => 160 (max_hits 8 )
# 471 / 1136     PDGF receptor-alpha => 145 (max_hits 1 )
# 472 / 1136     PDGF-AA => 1 (max_hits 1 )
# 473 / 1136     PDGF-AB => 1 (max_hits 1 )
# 474 / 1136     PDGF-BB => 2 (max_hits 1 )
# 475 / 1136     PDGF-C => 66 (max_hits 1 )
# 476 / 1136     PDGF-CC => 0 (max_hits 0 )
# 477 / 1136     PDGFb => 384 (max_hits 1 )
# 478 / 1136     PI 3-kinase => 217 (max_hits 4 )
# 479 / 1136     PI3 kinase => 209 (max_hits 1 )
# 480 / 1136     PKA => 746 (max_hits 3 )
# 481 / 1136     PKAII beta => 341 (max_hits 10 )
# 482 / 1136     PKC => 306 (max_hits 5 )
# 483 / 1136     PLA2 => 202 (max_hits 5 )
# 484 / 1136     PLC gamma 1 => 1148 (max_hits 7 )
# 485 / 1136     PP-1 alpha => 176 (max_hits 3 )
# 486 / 1136     PP-1 alpha 2 => 1139 (max_hits 3 )
# 487 / 1136     PP1 => 4391 (max_hits 10 )
# 488 / 1136     PP1C => 10 (max_hits 1 )
# 489 / 1136     PP2A => 3523 (max_hits 7 )
# 490 / 1136     PP2AC => 11 (max_hits 1 )
# 491 / 1136     PR => 11628 (max_hits 1 )
# 492 / 1136     PRAD1 => 7 (max_hits 1 )
# 493 / 1136     PRDI-BF1 => 7 (max_hits 1 )
# 494 / 1136     PRP9 => 27 (max_hits 4 )
# 495 / 1136     PS-2 => 279 (max_hits 1 )
# 496 / 1136     PS1 => 2058 (max_hits 5 )
# 497 / 1136     PS2 => 697 (max_hits 4 )
# 498 / 1136     PSD-95 => 31 (max_hits 1 )
# 499 / 1136     PTF => 14 (max_hits 2 )
# 500 / 1136     PTF alpha => 15 (max_hits 2 )
# 501 / 1136     PTPmu => 1 (max_hits 1 )
# 502 / 1136     PU.1 => 890 (max_hits 10 )
# 503 / 1136     Platelet-derived growth factor C => 619 (max_hits 10 )
# 504 / 1136     Presenilin 1 => 1767 (max_hits 10 )
# 505 / 1136     QM => 39 (max_hits 2 )
# 506 / 1136     RAD51 => 5350 (max_hits 1 )
# 507 / 1136     RAD52 => 1881 (max_hits 1 )
# 508 / 1136     RAD6 => 286 (max_hits 8 )
# 509 / 1136     RAF1 => 541 (max_hits 1 )
# 510 / 1136     RAFT => 1451 (max_hits 3 )
# 511 / 1136     RANTES => 29 (max_hits 1 )
# 512 / 1136     RAP74 => 18 (max_hits 2 )
# 513 / 1136     RAS => 135274 (max_hits 1 )
# 514 / 1136     RAS binding protein => 15120 (max_hits 1 )
# 515 / 1136     RB => 38300 (max_hits 2 )
# 516 / 1136     RBP => 106 (max_hits 9 )
# 517 / 1136     RBP1 => 684 (max_hits 1 )
# 518 / 1136     RBP2 => 468 (max_hits 1 )
# 519 / 1136     RII => 40 (max_hits 1 )
# 520 / 1136     RII alpha => 22 (max_hits 8 )
# 521 / 1136     RII beta => 358 (max_hits 10 )
# 522 / 1136     RII des-5 => 0 (max_hits 0 )
# 523 / 1136     RIN1 => 278 (max_hits 1 )
# 524 / 1136     RIP => 860 (max_hits 1 )
# 525 / 1136     RIZ => 7 (max_hits 1 )
# 526 / 1136     RNA polymerase II subunit 5 => 2369 (max_hits 2 )
# 527 / 1136     RPB5 => 952 (max_hits 10 )
# 528 / 1136     Rab11 => 4679 (max_hits 10 )
# 529 / 1136     Raf => 4756 (max_hits 3 )
# 530 / 1136     Raf-1 => 1727 (max_hits 1 )
# 531 / 1136     Raf-1 cysteine-rich domain => 2 (max_hits 1 )
# 532 / 1136     Raf-1 kinase => 1693 (max_hits 1 )
# 533 / 1136     Raf-1 protein kinase => 1323 (max_hits 1 )
# 534 / 1136     Raf-CRD => 0 (max_hits 0 )
# 535 / 1137    HTTPError
# 536 / 1136     Raf1 => 541 (max_hits 1 )
# 537 / 1136     Ras => 135274 (max_hits 1 )
# 538 / 1136     RasGAP => 527 (max_hits 2 )
# 539 / 1136     Rb => 38300 (max_hits 2 )
# 540 / 1136     Rb-associated protein => 1132 (max_hits 2 )
# 541 / 1136     RbAP46 => 13 (max_hits 2 )
# 542 / 1136     Rel => 1056 (max_hits 1 )
# 543 / 1136     Rhodanese => 7505 (max_hits 10 )
# 544 / 1136     S-phase-promoting factor => 4 (max_hits 1 )
# 545 / 1136     SA-beta-gal => 0 (max_hits 0 )
# 546 / 1136     SAKAP II => 6 (max_hits 6 )
# 547 / 1136     SCF => 1592 (max_hits 10 )
# 548 / 1136     SCYA24 => 2 (max_hits 1 )
# 549 / 1136     SCYA26 => 1 (max_hits 1 )
# 550 / 1136     SDF-1 => 28 (max_hits 1 )
# 551 / 1136     SF3a => 21 (max_hits 9 )
# 552 / 1136     SF3b => 31 (max_hits 1 )
# 553 / 1136     SH3 P17 => 11 (max_hits 1 )
# 554 / 1136     SHC => 3859 (max_hits 10 )
# 555 / 1136     SHPTP2 => 0 (max_hits 0 )
# 556 / 1136     SKR1 => 7 (max_hits 2 )
# 557 / 1136     SKR2 => 4 (max_hits 1 )
# 558 / 1136     SNAPc => 44 (max_hits 1 )
# 559 / 1136     SNAPc43 => 0 (max_hits 0 )
# 560 / 1136     SNX1 => 423 (max_hits 1 )
# 561 / 1136     SP1 => 1337 (max_hits 1 )
# 562 / 1136     SPF => 25 (max_hits 10 )
# 563 / 1136     SREBP-1 => 241 (max_hits 2 )
# 564 / 1136     SREBP-2 => 38 (max_hits 1 )
# 565 / 1136     SRF => 713 (max_hits 1 )
# 566 / 1136     SSRP => 7 (max_hits 1 )
# 567 / 1136     ST-3 => 23 (max_hits 1 )
# 568 / 1136     SV40 T antigen => 68 (max_hits 2 )
# 569 / 1136     SV40 large T antigen => 71 (max_hits 2 )
# 570 / 1136     Shc => 3859 (max_hits 10 )
# 571 / 1136     Smad4 => 714 (max_hits 1 )
# 572 / 1136     Snf => 14356 (max_hits 7 )
# 573 / 1136     Snf2 => 3821 (max_hits 9 )
# 574 / 1136     Sos => 1910 (max_hits 3 )
# 575 / 1136     Sos1 => 501 (max_hits 1 )
# 576 / 1136     Sp1 => 1337 (max_hits 1 )
# 577 / 1136     Spectrin cagliari => 0 (max_hits 0 )
# 578 / 1136     Src => 11418 (max_hits 1 )
# 579 / 1136     Src A box Nck-associated protein II => 528 (max_hits 1 )
# 580 / 1136     Stat1 => 430 (max_hits 1 )
# 581 / 1136     Stat3 => 589 (max_hits 1 )
# 582 / 1136     Stat5 => 36 (max_hits 1 )
# 583 / 1136     Sterile-5 => 524 (max_hits 5 )
# 584 / 1136     Swi => 13281 (max_hits 5 )
# 585 / 1136     Syk => 651 (max_hits 1 )
# 586 / 1136     Syntrophin => 3281 (max_hits 5 )
# 587 / 1136     T-cell receptor zeta chain => 116 (max_hits 2 )
# 588 / 1137    HTTPError
# 589 / 1136     TAF => 319 (max_hits 3 )
# 590 / 1136     TAFII110 => 1 (max_hits 1 )
# 591 / 1136     TAFII230 => 0 (max_hits 0 )
# 592 / 1136     TAFII250 => 17 (max_hits 8 )
# 593 / 1136     TAFII30 alpha => 8 (max_hits 8 )
# 594 / 1136     TAFII30 beta => 341 (max_hits 10 )
# 595 / 1136     TAFII40 => 2 (max_hits 1 )
# 596 / 1136     TAFII55 => 41 (max_hits 1 )
# 597 / 1136     TAFII60 => 2 (max_hits 1 )
# 598 / 1136     TAFIISPT3 => 0 (max_hits 0 )
# 599 / 1136     TAP => 2988 (max_hits 10 )
# 600 / 1136     TATA binding protein => 17697 (max_hits 10 )
# 601 / 1136     TATA binding subunit => 10066 (max_hits 10 )
# 602 / 1136     TATA box binding protein => 16185 (max_hits 10 )
# 603 / 1136     TATA box-binding protein => 16185 (max_hits 10 )
# 604 / 1136     TATA-binding protein => 16971 (max_hits 10 )
# 605 / 1136     TATA-binding protein-associated factor => 12739 (max_hits 10 )
# 606 / 1136     TBP => 4209 (max_hits 1 )
# 607 / 1136     TCR => 1133 (max_hits 1 )
# 608 / 1136     TFIIA-J => 0 (max_hits 0 )
# 609 / 1136     TFIIB => 1075 (max_hits 7 )
# 610 / 1136     TFIID => 21412 (max_hits 4 )
# 611 / 1136     TFIID beta => 378 (max_hits 4 )
# 612 / 1136     TFIIF => 188 (max_hits 4 )
# 613 / 1136     TFIIH => 1891 (max_hits 2 )
# 614 / 1136     TFIIIB => 1097 (max_hits 1 )
# 615 / 1136     TGF-beta => 4623 (max_hits 1 )
# 616 / 1136     TGFbeta => 44 (max_hits 4 )
# 617 / 1136     TH => 566 (max_hits 1 )
# 618 / 1136     TIMP => 1630 (max_hits 3 )
# 619 / 1136     TIMP-1 => 249 (max_hits 2 )
# 620 / 1136     TNF beta => 739 (max_hits 1 )
# 621 / 1136     TNF receptor 1 => 2770 (max_hits 1 )
# 622 / 1136     TNF receptor-1 => 1751 (max_hits 1 )
# 623 / 1136     TNF-R2 => 5 (max_hits 1 )
# 624 / 1136     TNF-alpha => 3730 (max_hits 2 )
# 625 / 1136     TNF-beta => 164 (max_hits 2 )
# 626 / 1136     TNF-related activation protein => 22 (max_hits 1 )
# 627 / 1136     TNFR-1 => 30 (max_hits 1 )
# 628 / 1136     TNFR-associated factor 2 => 1024 (max_hits 10 )
# 629 / 1136     TNFR1 => 244 (max_hits 1 )
# 630 / 1136     TNFalpha => 10 (max_hits 1 )
# 631 / 1136     TPO => 516 (max_hits 1 )
# 632 / 1136     TPO1 => 15 (max_hits 9 )
# 633 / 1136     TR subtype beta 1 => 1363 (max_hits 4 )
# 634 / 1136     TR2 => 26 (max_hits 2 )
# 635 / 1136     TR6 => 6 (max_hits 1 )
# 636 / 1136     TRADD => 489 (max_hits 1 )
# 637 / 1136     TRAF2 => 1536 (max_hits 1 )
# 638 / 1136     TRAP => 6337 (max_hits 1 )
# 639 / 1136     TRKB => 73 (max_hits 1 )
# 640 / 1136     TRKB receptor => 72 (max_hits 1 )
# 641 / 1136     TTR => 753 (max_hits 1 )
# 642 / 1136     Tat => 3158 (max_hits 1 )
# 643 / 1136     TcR zeta => 234 (max_hits 2 )
# 644 / 1136     TfR => 11 (max_hits 1 )
# 645 / 1136     Thrombopoietin => 939 (max_hits 1 )
# 646 / 1136     Torpedo 87K protein => 0 (max_hits 0 )
# 647 / 1136     Transthyretin => 899 (max_hits 1 )
# 648 / 1136     TrkA => 2927 (max_hits 10 )
# 649 / 1136     TrkB => 73 (max_hits 1 )
# 650 / 1136     TrkC => 34 (max_hits 1 )
# 651 / 1136     U2 small nuclear ribonucleoprotein => 19469 (max_hits 1 )
# 652 / 1136     U2 snRNP => 17439 (max_hits 4 )
# 653 / 1136     U2AF35 => 6 (max_hits 1 )
# 654 / 1136     U2AF65 => 20 (max_hits 5 )
# 655 / 1136     UBC2 => 65 (max_hits 10 )
# 656 / 1136     UBC9 => 1481 (max_hits 10 )
# 657 / 1136     UBE2I => 470 (max_hits 1 )
# 658 / 1136     UBF => 12 (max_hits 1 )
# 659 / 1136     UBL1 => 54 (max_hits 1 )
# 660 / 1136     USF => 223 (max_hits 2 )
# 661 / 1136     VEGF => 797 (max_hits 2 )
# 662 / 1136     VEGF-related protein => 109 (max_hits 1 )
# 663 / 1136     VP-16 => 0 (max_hits 0 )
# 664 / 1136     VP16 => 100 (max_hits 2 )
# 665 / 1136     VRP => 13 (max_hits 1 )
# 666 / 1136     Vascular endothelial growth factor => 5387 (max_hits 4 )
# 667 / 1136     Vascular endothelial growth factor-related protein => 76 (max_hits 1 )
# 668 / 1136     Vav => 1835 (max_hits 1 )
# 669 / 1136     WASP => 3132 (max_hits 1 )
# 670 / 1136     Wiskott-Aldrich syndrome protein => 4920 (max_hits 1 )
# 671 / 1136     XPB => 746 (max_hits 1 )
# 672 / 1136     XPD => 924 (max_hits 5 )
# 673 / 1136     XPG => 205 (max_hits 2 )
# 674 / 1136     YY1 => 2786 (max_hits 1 )
# 675 / 1136     aFGF => 17 (max_hits 1 )
# 676 / 1136     acidic (alpha 1-) syntrophin => 14 (max_hits 1 )
# 677 / 1136     acidic FGF => 36 (max_hits 10 )
# 678 / 1136     actin => 94869 (max_hits 5 )
# 679 / 1136     activin A => 3189 (max_hits 1 )
# 680 / 1136     activin beta => 499 (max_hits 10 )
# 681 / 1136     activin receptor => 4485 (max_hits 1 )
# 682 / 1136     activin type II receptor kinase => 62 (max_hits 1 )
# 683 / 1136     adenosine deaminase => 13059 (max_hits 1 )
# 684 / 1136     alpha 1-syntrophin => 530 (max_hits 8 )
# 685 / 1136     alpha spectrin => 1378 (max_hits 8 )
# 686 / 1136     alpha-1-antitrypsin => 1562 (max_hits 10 )
# 687 / 1136     alpha-Actinin-2 => 994 (max_hits 10 )
# 688 / 1136     alpha-actinin => 3877 (max_hits 1 )
# 689 / 1136     alpha1 syntrophin => 2 (max_hits 1 )
# 690 / 1136     alpha1AT => 4 (max_hits 1 )
# 691 / 1136     amyloid beta-protein => 7466 (max_hits 10 )
# 692 / 1136     angiotensin => 5032 (max_hits 2 )
# 693 / 1136     apolipoprotein E => 640 (max_hits 10 )
# 694 / 1136     apolipoprotein E2 => 141 (max_hits 10 )
# 695 / 1136     apolipoprotein E4 => 103 (max_hits 10 )
# 696 / 1136     apolipoproteins E => 115 (max_hits 10 )
# 697 / 1136     armadillo-protein => 14239 (max_hits 1 )
# 698 / 1136     aromatic L-amino acid decarboxylase => 1539 (max_hits 2 )
# 699 / 1136     bFGF => 23 (max_hits 1 )
# 700 / 1136     bHLH => 15023 (max_hits 3 )
# 701 / 1136     basic (beta 2-) syntrophin => 31 (max_hits 1 )
# 702 / 1136     basic FGF => 48 (max_hits 10 )
# 703 / 1136     bcl-2 => 7648 (max_hits 2 )
# 704 / 1136     beta 1 integrin => 4383 (max_hits 10 )
# 705 / 1136     beta 1-syntrophin => 1153 (max_hits 10 )
# 706 / 1136     beta 2-syntrophin => 902 (max_hits 10 )
# 707 / 1136     beta ARK => 355 (max_hits 1 )
# 708 / 1136     beta activin => 499 (max_hits 10 )
# 709 / 1136     beta inhibin => 2994 (max_hits 10 )
# 710 / 1136     beta spectrin => 4270 (max_hits 10 )
# 711 / 1136     beta-adrenergic receptor kinase => 832 (max_hits 1 )
# 712 / 1136     beta-amyloid peptide => 35 (max_hits 1 )
# 713 / 1136     beta-casein => 2721 (max_hits 5 )
# 714 / 1136     beta-catenin => 5611 (max_hits 7 )
# 715 / 1136     beta-galactosidase => 9462 (max_hits 1 )
# 716 / 1136     bicoid => 128 (max_hits 1 )
# 717 / 1136     bone morphogenetic protein (BMP)-2 => 339 (max_hits 1 )
# 718 / 1136     brain-derived neurotrophic factor => 600 (max_hits 1 )
# 719 / 1136     brain-derived neurotrophin => 5 (max_hits 1 )
# 720 / 1136     c-ABL => 397 (max_hits 1 )
# 721 / 1136     c-Abl => 397 (max_hits 1 )
# 722 / 1136     c-Cbl => 474 (max_hits 1 )
# 723 / 1136     c-Fos => 1305 (max_hits 1 )
# 724 / 1136     c-Jun => 2781 (max_hits 1 )
# 725 / 1136     c-Kit => 88 (max_hits 1 )
# 726 / 1136     c-Mpl => 18 (max_hits 1 )
# 727 / 1136     c-Myc => 2143 (max_hits 1 )
# 728 / 1136     c-Raf-1 => 556 (max_hits 1 )
# 729 / 1136     c-Src => 894 (max_hits 1 )
# 730 / 1136     c-cbl => 474 (max_hits 1 )
# 731 / 1136     c-fos => 1305 (max_hits 1 )
# 732 / 1136     c-jun => 2781 (max_hits 1 )
# 733 / 1136     c-myc => 2143 (max_hits 1 )
# 734 / 1136     cAMP-dependent protein kinase => 8852 (max_hits 3 )
# 735 / 1136     cAMP-dependent protein kinase II beta => 947 (max_hits 6 )
# 736 / 1136     cadherins, alpha => 15 (max_hits 8 )
# 737 / 1136     calcineurin => 9242 (max_hits 3 )
# 738 / 1136     calcium effector protein => 3 (max_hits 1 )
# 739 / 1136     calcium-sensing receptor => 8809 (max_hits 1 )
# 740 / 1136     calmodulin => 37543 (max_hits 1 )
# 741 / 1136     calnexin => 1786 (max_hits 1 )
# 742 / 1136     calnexin-associated protein => 61 (max_hits 1 )
# 743 / 1136     calreticulin => 2688 (max_hits 1 )
# 744 / 1136     cd44 => 566 (max_hits 1 )
# 745 / 1136     cdc2 => 1362 (max_hits 10 )
# 746 / 1136     cdc25 => 434 (max_hits 10 )
# 747 / 1136     cdc25A => 763 (max_hits 1 )
# 748 / 1136     cdc25B => 421 (max_hits 1 )
# 749 / 1136     cdc28 => 1039 (max_hits 10 )
# 750 / 1136     cdc7 => 850 (max_hits 1 )
# 751 / 1136     cdk2 => 1157 (max_hits 1 )
# 752 / 1136     chymase => 280 (max_hits 1 )
# 753 / 1136     ciliary neurotrophic factor => 1071 (max_hits 1 )
# 754 / 1136     collagen type I => 1256 (max_hits 10 )
# 755 / 1136     collagenase => 3401 (max_hits 10 )
# 756 / 1136     collagenase I => 26 (max_hits 10 )
# 757 / 1136     collagenase type I => 22 (max_hits 10 )
# 758 / 1136     creatine kinase => 3035 (max_hits 1 )
# 759 / 1136     cyclin A => 2815 (max_hits 1 )
# 760 / 1136     cyclin B => 1951 (max_hits 10 )
# 761 / 1136     cyclin B1 => 2174 (max_hits 2 )
# 762 / 1136     cyclin B2 => 1449 (max_hits 2 )
# 763 / 1136     cyclin D => 2432 (max_hits 10 )
# 764 / 1136     cyclin D-dependent kinase => 1038 (max_hits 1 )
# 765 / 1136     cyclin D1 => 1694 (max_hits 4 )
# 766 / 1136     cyclin D2 => 1328 (max_hits 6 )
# 767 / 1136     cyclin D3 => 1510 (max_hits 3 )
# 768 / 1136     cyclin E => 1176 (max_hits 10 )
# 769 / 1136     cyclin-dependent kinase 2 => 7607 (max_hits 10 )
# 770 / 1136     cyclin-dependent kinase interactor 1 => 1022 (max_hits 10 )
# 771 / 1136     cyclin-dependent kinase2 => 2 (max_hits 1 )
# 772 / 1136     cyclinA => 2 (max_hits 1 )
# 773 / 1136     cyclins A => 71 (max_hits 1 )
# 774 / 1136     cyclooxygenase-2 => 68 (max_hits 1 )
# 775 / 1136     cytochrome b558 => 240 (max_hits 10 )
# 776 / 1136     cytokeratin 18 => 1038 (max_hits 10 )
# 777 / 1136     cytokine receptor gamma chain => 42 (max_hits 1 )
# 778 / 1136     dTAFII40 => 0 (max_hits 0 )
# 779 / 1136     dTAFII60 => 0 (max_hits 0 )
# 780 / 1136     dTBP => 1 (max_hits 1 )
# 781 / 1136     dTFIID => 1 (max_hits 1 )
# 782 / 1136     decorin => 654 (max_hits 1 )
# 783 / 1136     decoy receptor 3 => 1038 (max_hits 1 )
# 784 / 1136     delta C-4 => 593 (max_hits 9 )
# 785 / 1136     delta C-43 => 9 (max_hits 9 )
# 786 / 1136     delta-catenin => 2400 (max_hits 1 )
# 787 / 1136     dipeptidyl peptidase IV => 102 (max_hits 1 )
# 788 / 1136     dystrophin => 2735 (max_hits 1 )
# 789 / 1136     dystrophin related protein => 616 (max_hits 1 )
# 790 / 1136     e compl => 112 (max_hits 10 )
# 791 / 1136     eip1 => 4 (max_hits 1 )
# 792 / 1136     elastin => 2874 (max_hits 1 )
# 793 / 1136     endothelial growth factor => 5491 (max_hits 4 )
# 794 / 1136     endothelin-1 => 3457 (max_hits 1 )
# 795 / 1136     eotaxin => 459 (max_hits 10 )
# 796 / 1136     eotaxin-2 => 19 (max_hits 1 )
# 797 / 1136     eotaxin-3 => 14 (max_hits 1 )
# 798 / 1136     epidermal growth factor => 14513 (max_hits 1 )
# 799 / 1136     epidermal growth factor receptor => 6406 (max_hits 1 )
# 800 / 1136     erythropoietin => 1032 (max_hits 1 )
# 801 / 1136     erythropoietin (EPO) receptor => 10 (max_hits 1 )
# 802 / 1136     erythropoietin receptor => 524 (max_hits 1 )
# 803 / 1136     fetal liver kinase 1 => 1031 (max_hits 10 )
# 804 / 1136     fibrinogen B beta chain => 379 (max_hits 10 )
# 805 / 1136     fibroblast growth factor receptor 2 => 2821 (max_hits 1 )
# 806 / 1136     fibroblast growth factor receptor 3 => 2574 (max_hits 1 )
# 807 / 1136     fibroblast growth factor-7 => 563 (max_hits 1 )
# 808 / 1136     fibromodulin => 659 (max_hits 1 )
# 809 / 1136     fibronectin => 19797 (max_hits 1 )
# 810 / 1136     filamin => 5379 (max_hits 3 )
# 811 / 1136     gIII => 37 (max_hits 6 )
# 812 / 1136     gammac => 8 (max_hits 1 )
# 813 / 1136     gastrin => 2213 (max_hits 1 )
# 814 / 1136     gelatinase A => 150 (max_hits 1 )
# 815 / 1136     gelatinase B => 116 (max_hits 10 )
# 816 / 1136     glial fibrillary acidic protein => 690 (max_hits 1 )
# 817 / 1136     glucocorticoid-induced TNFR-related (mGITR) protein => 0 (max_hits 0 )
# 818 / 1136     glut 1 => 1055 (max_hits 1 )
# 819 / 1136     glutamine synthetase => 9727 (max_hits 1 )
# 820 / 1136     glycogen synthase kinase 3 => 2871 (max_hits 10 )
# 821 / 1136     gp 130 => 156 (max_hits 1 )
# 822 / 1136     gp120 => 21 (max_hits 1 )
# 823 / 1136     gp12O => 0 (max_hits 0 )
# 824 / 1136     gp130 => 123 (max_hits 5 )
# 825 / 1136     gp91-phox => 11 (max_hits 1 )
# 826 / 1136     granulocyte-macrophage colony-stimulating factor => 782 (max_hits 1 )
# 827 / 1136     granulysin => 101 (max_hits 1 )
# 828 / 1136     groEL => 1810 (max_hits 10 )
# 829 / 1136     growth arrest-specific gene 6 => 1025 (max_hits 10 )
# 830 / 1136     growth factor receptor-bound protein 2 => 1835 (max_hits 10 )
# 831 / 1136     growth hormone => 6235 (max_hits 3 )
# 832 / 1136     h-TR beta 1 => 1359 (max_hits 10 )
# 833 / 1136     hDP-1 => 6 (max_hits 4 )
# 834 / 1136     hDP-2 => 0 (max_hits 0 )
# 835 / 1136     hFGFR-1 => 0 (max_hits 0 )
# 836 / 1136     hGH => 6 (max_hits 4 )
# 837 / 1136     hGHR => 0 (max_hits 0 )
# 838 / 1136     hGITR => 0 (max_hits 0 )
# 839 / 1136     hGITRL => 1 (max_hits 1 )
# 840 / 1136     hGM-CSF => 0 (max_hits 0 )
# 841 / 1136     hGM-CSF-R => 0 (max_hits 0 )
# 842 / 1136     hIL-10 => 1 (max_hits 1 )
# 843 / 1136     hIL-10R => 1 (max_hits 1 )
# 844 / 1136     hIL-6 => 2 (max_hits 1 )
# 845 / 1136     hIL-6R => 0 (max_hits 0 )
# 846 / 1136     hLIF => 0 (max_hits 0 )
# 847 / 1136     hLIF-R => 0 (max_hits 0 )
# 848 / 1136     hPRL => 1 (max_hits 1 )
# 849 / 1136     hPRLR => 0 (max_hits 0 )
# 850 / 1137    HTTPError
# 851 / 1136     hTAF31 => 0 (max_hits 0 )
# 852 / 1136     hTAF80 => 0 (max_hits 0 )
# 853 / 1136     hTAFII => 0 (max_hits 0 )
# 854 / 1136     hTAFII18 => 0 (max_hits 0 )
# 855 / 1136     hTAFII20 => 0 (max_hits 0 )
# 856 / 1136     hTAFII250 => 0 (max_hits 0 )
# 857 / 1136     hTAFII28 => 12 (max_hits 1 )
# 858 / 1136     hTAFII30 => 0 (max_hits 0 )
# 859 / 1136     hTAFII32 => 0 (max_hits 0 )
# 860 / 1136     hTFIID => 0 (max_hits 0 )
# 861 / 1136     hTFIID alpha => 8 (max_hits 8 )
# 862 / 1136     hTFIID beta => 341 (max_hits 10 )
# 863 / 1136     hdm-2 => 1 (max_hits 1 )
# 864 / 1136     heat shock protein 90 => 6688 (max_hits 10 )
# 865 / 1136     herpes virus entry mediator ( HVEM ) - L => 280 (max_hits 10 )
# 866 / 1136     herpes virus entry mediator (HVEM)-L => 2 (max_hits 1 )
# 867 / 1136     histone H1 => 7352 (max_hits 1 )
# 868 / 1136     hsp70 => 9085 (max_hits 10 )
# 869 / 1136     hsp90 => 3992 (max_hits 10 )
# 870 / 1136     human growth hormone => 16 (max_hits 1 )
# 871 / 1136     hyaluronic acid synthase 2 => 1031 (max_hits 2 )
# 872 / 1136     hyaluronidase => 5222 (max_hits 4 )
# 873 / 1136     ifnar1 => 340 (max_hits 1 )
# 874 / 1136     ifnar2 => 313 (max_hits 1 )
# 875 / 1136     immunoreceptor tyrosine-based activation motif => 9 (max_hits 1 )
# 876 / 1136     inhibitor 2 => 18754 (max_hits 10 )
# 877 / 1136     insulin => 26396 (max_hits 1 )
# 878 / 1136     insulin receptor => 7726 (max_hits 1 )
# 879 / 1136     insulin receptor substrate 1 => 2162 (max_hits 1 )
# 880 / 1136     insulin receptor substrate-1 => 1144 (max_hits 1 )
# 881 / 1136     insulin-like growth factor-I => 761 (max_hits 1 )
# 882 / 1136     insulin-like growth factor-I (IGF-I) receptor => 39 (max_hits 1 )
# 883 / 1136     insulin-like growth factor-I receptor => 71 (max_hits 1 )
# 884 / 1136     interferon (IFN)alpha2 => 2 (max_hits 1 )
# 885 / 1136     interferon alpha => 5742 (max_hits 8 )
# 886 / 1136     interferon alpha (IFNalpha) receptor => 11 (max_hits 1 )
# 887 / 1136     interferon alpha receptor => 1515 (max_hits 1 )
# 888 / 1136     interferon regulatory factor 4 => 1959 (max_hits 10 )
# 889 / 1136     interferon-alpha => 5734 (max_hits 10 )
# 890 / 1136     interferon-gamma => 4066 (max_hits 1 )
# 891 / 1136     interferon-gamma inducing factor => 67 (max_hits 1 )
# 892 / 1136     interleukin (IL) 1 => 1603 (max_hits 10 )
# 893 / 1136     interleukin (IL) 2 receptor => 1181 (max_hits 1 )
# 894 / 1136     interleukin (IL) 6 => 1156 (max_hits 10 )
# 895 / 1136     interleukin (IL)-13 => 1033 (max_hits 1 )
# 896 / 1136     interleukin (IL)-8 => 1020 (max_hits 1 )
# 897 / 1136     interleukin 10 => 3524 (max_hits 10 )
# 898 / 1136     interleukin 10 (IL-10) receptor => 1053 (max_hits 1 )
# 899 / 1136     interleukin 13 => 2579 (max_hits 10 )
# 900 / 1136     interleukin 13 receptor => 2251 (max_hits 1 )
# 901 / 1136     interleukin 13 receptor alpha chain => 1057 (max_hits 1 )
# 902 / 1136     interleukin 1alpha => 8 (max_hits 1 )
# 903 / 1136     interleukin 2 => 8649 (max_hits 10 )
# 904 / 1136     interleukin 2 receptor => 7015 (max_hits 1 )
# 905 / 1136     interleukin-1 => 14051 (max_hits 2 )
# 906 / 1136     interleukin-1 beta => 2120 (max_hits 10 )
# 907 / 1136     interleukin-1 beta-converting enzyme => 14 (max_hits 1 )
# 908 / 1136     interleukin-1 receptor => 11962 (max_hits 1 )
# 909 / 1136     interleukin-10 => 2518 (max_hits 1 )
# 910 / 1136     interleukin-10 receptor => 1691 (max_hits 1 )
# 911 / 1136     interleukin-15 => 1044 (max_hits 1 )
# 912 / 1136     interleukin-1beta => 22 (max_hits 1 )
# 913 / 1136     interleukin-1beta (IL-1beta) converting enzyme => 1 (max_hits 1 )
# 914 / 1136     interleukin-1beta converting enzyme => 6 (max_hits 1 )
# 915 / 1136     interleukin-2 => 7628 (max_hits 1 )
# 916 / 1136     interleukin-2 (IL-2) receptor => 160 (max_hits 1 )
# 917 / 1136     interleukin-2 receptor => 5994 (max_hits 1 )
# 918 / 1136     interleukin-3 => 4065 (max_hits 1 )
# 919 / 1136     interleukin-6 => 2869 (max_hits 1 )
# 920 / 1136     interleukin-6 receptor => 1643 (max_hits 1 )
# 921 / 1136     interleukin-8 => 1742 (max_hits 10 )
# 922 / 1136     isorenin => 0 (max_hits 0 )
# 923 / 1136     ith => 1 (max_hits 1 )
# 924 / 1136     junB => 435 (max_hits 1 )
# 925 / 1136     keratinocyte growth factor => 47 (max_hits 1 )
# 926 / 1136     keratinocyte growth factor receptor => 19 (max_hits 1 )
# 927 / 1136     kinase insert domain-containing receptor => 1 (max_hits 1 )
# 928 / 1136     lacZ => 30 (max_hits 10 )
# 929 / 1136     laminin 1 => 4505 (max_hits 10 )
# 930 / 1136     laminin-5 => 723 (max_hits 1 )
# 931 / 1136     leucine utilization => 0 (max_hits 0 )
# 932 / 1136     leukemia inhibitory factor => 1079 (max_hits 1 )
# 933 / 1136     light subunit neurofilament protein => 3 (max_hits 2 )
# 934 / 1136     lymphotoxin => 839 (max_hits 2 )
# 935 / 1136     lymphotoxin alpha => 394 (max_hits 8 )
# 936 / 1136     lymphotoxin beta => 803 (max_hits 10 )
# 937 / 1136     lymphotoxin beta receptor => 580 (max_hits 1 )
# 938 / 1136     lymphotoxin-alpha => 386 (max_hits 1 )
# 939 / 1136     lymphotoxin-beta => 462 (max_hits 1 )
# 940 / 1136     mGITR => 0 (max_hits 0 )
# 941 / 1136     mIL-10R => 1 (max_hits 1 )
# 942 / 1136     macrophage inflammatory protein (MIP)-1alpha => 33 (max_hits 1 )
# 943 / 1136     matrix metalloprotease-2 => 20 (max_hits 1 )
# 944 / 1136     mdm-2 => 120 (max_hits 1 )
# 945 / 1136     microtubule-associated protein 2 => 4836 (max_hits 10 )
# 946 / 1136     mitogen-activated protein kinase => 46252 (max_hits 10 )
# 947 / 1136     mitogen-activated protein kinase kinase => 46252 (max_hits 7 )
# 948 / 1136     mitogen-activated protein-serine (MAP) kinases => 31 (max_hits 1 )
# 949 / 1136     monocyte chemoattractant protein-3 => 8 (max_hits 1 )
# 950 / 1136     myeloid progenitor inhibitory factor 2 => 1022 (max_hits 10 )
# 951 / 1136     myeloproliferative leukemia virus receptor => 66 (max_hits 1 )
# 952 / 1136     myogenic basic helix-loop-helix => 6 (max_hits 1 )
# 953 / 1136     myogenin => 521 (max_hits 1 )
# 954 / 1136     natural resistance-associated protein => 1210 (max_hits 1 )
# 955 / 1136     nerve growth factor => 2289 (max_hits 1 )
# 956 / 1136     neuregulin-2 => 646 (max_hits 1 )
# 957 / 1136     neuregulin-2beta => 0 (max_hits 0 )
# 958 / 1136     neuromodulin => 682 (max_hits 10 )
# 959 / 1136     neuropilin-1 => 1426 (max_hits 1 )
# 960 / 1136     neurotrophin TRKB receptor => 12 (max_hits 1 )
# 961 / 1136     neurotrophin-3 => 579 (max_hits 1 )
# 962 / 1136     nexin => 24117 (max_hits 10 )
# 963 / 1136     nuclear factor kappa B => 6150 (max_hits 10 )
# 964 / 1136     nuclear factor-kappaB => 606 (max_hits 1 )
# 965 / 1136     nucleobindin => 1478 (max_hits 2 )
# 966 / 1136     nucleolin => 4314 (max_hits 1 )
# 967 / 1136     osteogenic protein (OP)-1 => 0 (max_hits 0 )
# 968 / 1136     p0071 => 3 (max_hits 1 )
# 969 / 1136     p103 => 4 (max_hits 2 )
# 970 / 1136     p105Rb => 0 (max_hits 0 )
# 971 / 1136     p107 => 269 (max_hits 1 )
# 972 / 1136     p110RB => 0 (max_hits 0 )
# 973 / 1136     p120GAP => 3 (max_hits 1 )
# 974 / 1136     p130 => 317 (max_hits 2 )
# 975 / 1136     p140trk => 0 (max_hits 0 )
# 976 / 1136     p140trk (trkA) tyrosine kinase receptor => 1 (max_hits 1 )
# 977 / 1136     p15 => 1545 (max_hits 10 )
# 978 / 1136     p16 => 70 (max_hits 8 )
# 979 / 1136     p16INK4a => 7 (max_hits 1 )
# 980 / 1136     p19 => 240 (max_hits 8 )
# 981 / 1136     p21 => 7191 (max_hits 5 )
# 982 / 1136     p21CIP1 => 5 (max_hits 1 )
# 983 / 1136     p21rac => 2 (max_hits 1 )
# 984 / 1136     p21ras => 8 (max_hits 1 )
# 985 / 1136     p22 => 368 (max_hits 6 )
# 986 / 1136     p22-phox => 15 (max_hits 1 )
# 987 / 1136     p23 => 475 (max_hits 10 )
# 988 / 1136     p27 => 972 (max_hits 10 )
# 989 / 1136     p27Kip1 => 25 (max_hits 5 )
# 990 / 1136     p27Kip1 kinase => 18 (max_hits 5 )
# 991 / 1136     p300 => 4041 (max_hits 1 )
# 992 / 1136     p32 => 60 (max_hits 6 )
# 993 / 1136     p33cdk2 => 0 (max_hits 0 )
# 994 / 1136     p34 => 937 (max_hits 5 )
# 995 / 1136     p34cdc2 => 20 (max_hits 1 )
# 996 / 1136     p44 => 124 (max_hits 6 )
# 997 / 1136     p47-phox => 6 (max_hits 1 )
# 998 / 1136     p47nck => 0 (max_hits 0 )
# 999 / 1136     p48 => 80 (max_hits 10 )
# 1000 / 1136     p50 => 256 (max_hits 4 )
# 1001 / 1136     p52Shc => 1 (max_hits 1 )
# 1002 / 1136     p53 => 11169 (max_hits 9 )
# 1003 / 1136     p54 => 711 (max_hits 3 )
# 1004 / 1136     p55 => 5271 (max_hits 3 )
# 1005 / 1136     p56lck => 7 (max_hits 1 )
# 1006 / 1136     p57 => 27 (max_hits 3 )
# 1007 / 1136     p59fyn => 1 (max_hits 1 )
# 1008 / 1136     p60 => 3617 (max_hits 6 )
# 1009 / 1136     p62 => 1454 (max_hits 4 )
# 1010 / 1136     p66WASP => 0 (max_hits 0 )
# 1011 / 1136     p67-phox => 7 (max_hits 1 )
# 1012 / 1136     p72Syk => 1 (max_hits 1 )
# 1013 / 1136     p75 => 566 (max_hits 5 )
# 1014 / 1136     p75 neurotrophin receptor => 24 (max_hits 1 )
# 1015 / 1136     p76 => 17 (max_hits 2 )
# 1016 / 1136     p80 => 1857 (max_hits 3 )
# 1017 / 1136     p85 => 231 (max_hits 1 )
# 1018 / 1136     p90 => 101 (max_hits 1 )
# 1019 / 1136     p9Ckshs1 => 0 (max_hits 0 )
# 1020 / 1136     pRB => 21 (max_hits 1 )
# 1021 / 1136     pRb => 21 (max_hits 1 )
# 1022 / 1136     pRb2 => 10 (max_hits 1 )
# 1023 / 1136     perforin => 2337 (max_hits 1 )
# 1024 / 1136     phFGFR => 0 (max_hits 0 )
# 1025 / 1136     phosphatase 2B => 3459 (max_hits 2 )
# 1026 / 1136     phosphatidylinositol (PI) 3-kinase => 111 (max_hits 10 )
# 1027 / 1136     phosphatidylinositol 3-kinase => 11641 (max_hits 1 )
# 1028 / 1136     phosphatidylinositol-3 (PI-3) kinase => 111 (max_hits 10 )
# 1029 / 1136     phosphoCREB => 0 (max_hits 0 )
# 1030 / 1136     phospholipase C-gamma => 1063 (max_hits 2 )
# 1031 / 1136     phospholipase C-gamma 1 => 1983 (max_hits 10 )
# 1032 / 1136     pim 2 => 2454 (max_hits 1 )
# 1033 / 1136     plasminogen activator inhibitor-1 => 2072 (max_hits 10 )
# 1034 / 1136     platelet endothelial cell adhesion molecule (PECAM) 1 => 1027 (max_hits 10 )
# 1035 / 1136     platelet factor XIII => 6 (max_hits 2 )
# 1036 / 1136     platelet-derived growth factor => 4546 (max_hits 2 )
# 1037 / 1136     platelet-derived growth factor (PDGF) C => 59 (max_hits 10 )
# 1038 / 1136     platelet-derived growth factor (PDGF) receptor => 48 (max_hits 1 )
# 1039 / 1136     platelet-derived growth factor BB => 4 (max_hits 2 )
# 1040 / 1136     pp120 => 2 (max_hits 1 )
# 1041 / 1136     pp42 => 2 (max_hits 1 )
# 1042 / 1136     pp54 => 0 (max_hits 0 )
# 1043 / 1136     pp60c-src => 9 (max_hits 1 )
# 1044 / 1136     pp60src => 0 (max_hits 0 )
# 1045 / 1136     pp60v-src => 3 (max_hits 1 )
# 1046 / 1136     pp66 => 1 (max_hits 1 )
# 1047 / 1136     presenilin (PS) 1 => 1035 (max_hits 10 )
# 1048 / 1136     presenilin 1 => 1767 (max_hits 10 )
# 1049 / 1136     procollagen I => 54 (max_hits 10 )
# 1050 / 1136     progesterone receptor => 2134 (max_hits 1 )
# 1051 / 1136     prolactin => 5702 (max_hits 1 )
# 1052 / 1136     proliferating-cell nuclear antigen => 2422 (max_hits 1 )
# 1053 / 1136     protein kinase A => 24017 (max_hits 1 )
# 1054 / 1136     protein kinase C => 21911 (max_hits 10 )
# 1055 / 1136     protein phosphatase 1 => 48112 (max_hits 10 )
# 1056 / 1136     protein phosphatase inhibitor => 7883 (max_hits 10 )
# 1057 / 1136     protein phosphatase inhibitor 2 => 2648 (max_hits 10 )
# 1058 / 1136     protein phosphatase type 1 => 6255 (max_hits 10 )
# 1059 / 1136     proximal sequence element (PSE)-binding transcription factor => 0 (max_hits 0 )
# 1060 / 1136     rIL-10R => 0 (max_hits 0 )
# 1061 / 1136     rMMP-1 => 0 (max_hits 0 )
# 1062 / 1136     rTIMP => 0 (max_hits 0 )
# 1063 / 1136     rTIMP-1 => 0 (max_hits 0 )
# 1064 / 1136     raf-1 => 1727 (max_hits 1 )
# 1065 / 1136     raf1 => 541 (max_hits 1 )
# 1066 / 1136     ras => 135274 (max_hits 1 )
# 1067 / 1136     receptor interacting protein => 18149 (max_hits 1 )
# 1068 / 1136     recombinant human tissue inhibitor of metalloproteinases-1 => 0 (max_hits 0 )
# 1069 / 1136     renin => 1736 (max_hits 1 )
# 1070 / 1136     replication factor 1a => 26 (max_hits 10 )
# 1071 / 1136     retinoblastoma => 3998 (max_hits 10 )
# 1072 / 1136     retinoblastoma protein => 3943 (max_hits 3 )
# 1073 / 1136     retinoblastoma susceptibility gene => 1 (max_hits 1 )
# 1074 / 1136     retinoblastoma tumor suppressor protein => 21 (max_hits 1 )
# 1075 / 1136     retinoic X receptor => 1287 (max_hits 1 )
# 1076 / 1136     retinol-binding protein => 4007 (max_hits 6 )
# 1077 / 1136     rhodanese => 7505 (max_hits 10 )
# 1078 / 1136     s-IL1R => 1 (max_hits 1 )
# 1079 / 1136     sCAM => 15 (max_hits 1 )
# 1080 / 1136     sE-selectin => 0 (max_hits 0 )
# 1081 / 1136     sICAM-1 => 0 (max_hits 0 )
# 1082 / 1136     sIL-2R => 0 (max_hits 0 )
# 1083 / 1136     sIL-6R => 0 (max_hits 0 )
# 1084 / 1136     sVCAM-1 => 0 (max_hits 0 )
# 1085 / 1136     sem-5 => 12 (max_hits 1 )
# 1086 / 1136     senescence-associated beta-galactosidase => 0 (max_hits 0 )
# 1087 / 1136     serine-threonine phosphatase 2A => 15760 (max_hits 6 )
# 1088 / 1136     serine-threonine phosphatase 2A catalytic subunit => 1851 (max_hits 6 )
# 1089 / 1136     serum response factor => 1975 (max_hits 1 )
# 1090 / 1136     simian virus 40 T antigen => 1044 (max_hits 2 )
# 1091 / 1136     soluble cell adhesion molecules => 2 (max_hits 1 )
# 1092 / 1136     sorting nexin-1 => 1026 (max_hits 1 )
# 1093 / 1136     stromelysin-3 => 763 (max_hits 10 )
# 1094 / 1136     syndecan => 3497 (max_hits 4 )
# 1095 / 1136     tapasin => 1200 (max_hits 10 )
# 1096 / 1136     thrombopoietin => 939 (max_hits 1 )
# 1097 / 1136     thyroid AKAP => 1 (max_hits 1 )
# 1098 / 1136     tissue inhibitor of metalloproteinases-1 => 19 (max_hits 1 )
# 1099 / 1136     tonin => 8 (max_hits 1 )
# 1100 / 1136     transcription factor IIB => 3431 (max_hits 1 )
# 1101 / 1136     transcription factor IID => 250 (max_hits 1 )
# 1102 / 1136     transferrin => 3275 (max_hits 1 )
# 1103 / 1136     transferrin receptor => 1889 (max_hits 1 )
# 1104 / 1136     transforming growth factor beta => 11434 (max_hits 10 )
# 1105 / 1136     transforming growth factor-beta => 11093 (max_hits 4 )
# 1106 / 1136     transforming growth factor-beta 1 => 5090 (max_hits 10 )
# 1107 / 1136     transforming growth factors (TGF) beta1 => 4 (max_hits 2 )
# 1108 / 1136     transporter associated with antigen processing => 357 (max_hits 1 )
# 1109 / 1136     transthyretin => 899 (max_hits 1 )
# 1110 / 1136     trk => 1411 (max_hits 5 )
# 1111 / 1136     trkA => 2927 (max_hits 10 )
# 1112 / 1136     trypsin => 23419 (max_hits 3 )
# 1113 / 1136     tumor necrosis factor (TNF) receptor-1 => 154 (max_hits 1 )
# 1114 / 1136     tumor necrosis factor (TNF) type 2 receptor => 1054 (max_hits 1 )
# 1115 / 1136     tumor necrosis factor alpha => 7351 (max_hits 8 )
# 1116 / 1136     tumor necrosis factor receptor I => 64 (max_hits 1 )
# 1117 / 1136     tumor necrosis factor-alpha => 7343 (max_hits 3 )
# 1118 / 1136     tumour necrosis factor-alpha => 7 (max_hits 1 )
# 1119 / 1136     tumour necrosis factors (TNF) alpha => 8 (max_hits 8 )
# 1120 / 1136     type 1 protein phosphatase => 6255 (max_hits 10 )
# 1121 / 1136     type I IL-1 receptor => 63 (max_hits 1 )
# 1122 / 1136     type I interferon-receptor => 168 (max_hits 10 )
# 1123 / 1136     type II cAMP-dependent protein kinase => 1712 (max_hits 6 )
# 1124 / 1136     type IV collagen => 3455 (max_hits 1 )
# 1125 / 1136     type-I IL1R => 4 (max_hits 1 )
# 1126 / 1136     type-I interleukin-1 receptor => 382 (max_hits 1 )
# 1127 / 1136     tyrosine hydroxylase => 682 (max_hits 1 )
# 1128 / 1136     tyrosine kinase, phosphatidylinositol 3-kinase => 52 (max_hits 1 )
# 1129 / 1136     upstream binding factor => 1049 (max_hits 1 )
# 1130 / 1136     utrophin => 800 (max_hits 1 )
# 1131 / 1136     v-Fos => 272 (max_hits 1 )
# 1132 / 1136     v-Raf => 290 (max_hits 1 )
# 1133 / 1136     vascular endothelial growth factor => 5387 (max_hits 4 )
# 1134 / 1136     vimentin => 1462 (max_hits 1 )
# 1135 / 1136     viral protein 16 => 1024 (max_hits 10 )
# 1136 / 1136     vitamin D receptor => 535 (max_hits 1 )

# %%
new_data.insert(0, label)

# %%
new_data
# Out:
# [['protein', 'appearances', 'hits', 'max_score_hits'],
#  ['ClpX', 6, 2319, 1],
#  ['ComK', 10, 166, 3],
#  ['CsbB', 2, 4, 3],
#  ['CtsR', 6, 226, 1],
#  ['DnaK', 8, 2136, 10],
#  ['E sigma E', 6, 1007, 10],
#  ['EsigmaF', 8, 0, 0],
#  ['FlgM', 13, 514, 10],
#  ['FtsZ', 25, 2955, 10],
#  ['GerE', 210, 28, 10],
#  ['KatX', 8, 8, 7],
#  ['KinC', 2, 4, 3],
#  ['KinD', 2, 212, 2],
#  ['PBP4*', 7, 88, 10],
#  ['PhoP~P', 3, -1, 0],
#  ['RacX', 7, 38, 1],
#  ['RbsW', 8, 0, 0],
#  ['RocR', 4, 17, 2],
#  ['SigE', 6, 523, 10],
#  ['SigK', 12, 146, 10],
#  ['SigL', 5, 11, 4],
#  ['Spo0', 1, 0, 0],
#  ['Spo0A', 13, 174, 10],
#  ['Spo0A~P', 2, -1, 0],
#  ['SpoIIAA', 23, 86, 10],
#  ['SpoIIAA-P', 12, 0, 0],
#  ['SpoIIAB', 14, 58, 10],
#  ['SpoIIE', 75, 1079, 10],
#  ['SpoIIID', 60, 123, 10],
#  ['YdjP', 7, 11, 4],
#  ['YfhM', 7, 124, 7],
#  ['YfhP', 6, 4, 2],
#  ['YknXYZ', 7, 0, 0],
#  ['YteI', 7, 0, 0],
#  ['YtxH', 3, 545, 1],
#  ['YuaG', 7, 0, 0],
#  ['YvyD', 3, 2, 1],
#  ['ald', 9, 1145, 10],
#  ['araE', 1, 20, 10],
#  ['bkd', 1, 40, 1],
#  ['bmrUR', 7, 0, 0],
#  ['clpC', 12, 539, 10],
#  ['comF', 5, 817, 1],
#  ['cot', 39, 258, 10],
#  ['cotB', 80, 3, 3],
#  ['cotC', 80, 3, 3],
#  ['cotD', 76, 25, 7],
#  ['cotX', 83, 2, 1],
#  ['cwlH', 2, 2, 1],
#  ['degR', 15, 2, 2],
#  ['flgM', 5, 514, 10],
#  ['ftsY', 2, 1718, 10],
#  ['gerE', 40, 28, 10],
#  ['gsiB', 2, 171, 10],
#  ['hag', 5, 41, 10],
#  ['katX', 24, 8, 7],
#  ['kdgR', 1, 142, 10],
#  ['nadE', 1, 1117, 10],
#  ['phrC', 1, 10, 2],
#  ['rocG', 8, 3, 3],
#  ['rsfA', 2, 220, 3],
#  ['sigB', 2, 447, 10],
#  ['sigE', 27, 523, 10],
#  ['sigK', 38, 146, 10],
#  ['sigW', 1, 40, 10],
#  ['sigX', 3, 90, 10],
#  ['sigma 28', 8, 1108, 10],
#  ['sigma 32', 8, 1047, 10],
#  ['sigma B', 11, 170, 10],
#  ['sigma F', 9, 368, 10],
#  ['sigma G', 8, 278, 10],
#  ['sigma W', 7, 64, 10],
#  ['sigma X', 2, 44, 10],
#  ['sigma(54)', 4, 5476, 3],
#  ['sigma(A)', 7, 113, 1],
#  ['sigma(B)', 3, 142, 2],
#  ['sigma(F)', 7, 281, 10],
#  ['sigma(G)', 4, -1, 0],
#  ['sigma(H)', 5, 26, 1],
#  ['sigma(K)', 44, 7, 1],
#  ['sigma(X)', 3, 7, 3],
#  ['sigmaA', 34, 1, 1],
#  ['sigmaB', 87, 0, 0],
#  ['sigmaD', 15, 0, 0],
#  ['sigmaE', 1, 2, 1],
#  ['sigmaF', 59, 1, 1],
#  ['sigmaG', 15, 0, 0],
#  ['sigmaH', 22, 0, 0],
#  ['sigmaK', 106, 266, 1],
#  ['sigmaL', 9, 0, 0],
#  ['sigmaW', 1, 0, 0],
#  ['spo0A', 2, 174, 10],
#  ['spo0H', 1, 0, 0],
#  ['spoIIG', 4, 0, 0],
#  ['spoIVA', 1, 121, 10],
#  ['spoVG', 2, 223, 10],
#  ['sspE', 6, 2, 2],
#  ['sspG', 3, 1, 1],
#  ['sspH', 6, 1, 1],
#  ['sspJ', 3, 12, 5],
#  ['sspL', 6, 24, 10],
#  ['sspN', 6, 512, 1],
#  ['tagA', 3, 458, 8],
#  ['tagD', 3, 167, 10],
#  ['tlp', 6, 121, 10],
#  ['tuaA', 3, 36, 1],
#  ['ydaE', 7, 1, 1],
#  ['ydaG', 7, 2, 2],
#  ['ydaP', 7, 2, 1],
#  ['ydhD', 6, 3, 2],
#  ['yfhP', 6, 4, 2],
#  ['yfhQ', 6, 1, 1],
#  ['yfhR', 6, 17, 2],
#  ['yfhS', 6, 2, 1],
#  ['yfkM', 7, 1, 1],
#  ['ykuD', 6, 5, 1],
#  ['ykvP', 6, 1, 1],
#  ['ykzA', 1, 0, 0],
#  ['ypuN', 3, 0, 0],
#  ['yvyD', 36, 2, 1],
#  ['ywhE', 2, 0, 0]]

# %%
import csv
filename = "lll_bioc_result.csv"
with open("data_query/PROT/"+filename, "w") as f:
    writer = csv.writer(f, lineterminator='\n')#ここ大事
    writer.writerows(new_data)

# %%
new_data_row_2 = [row[2] for row in new_data]

# %%
new_data_row_2
# Out:
# [2319,
#  166,
#  4,
#  226,
#  2136,
#  1007,
#  0,
#  514,
#  2955,
#  28,
#  8,
#  4,
#  212,
#  88,
#  -1,
#  38,
#  0,
#  17,
#  523,
#  146,
#  11,
#  0,
#  174,
#  -1,
#  86,
#  0,
#  58,
#  1079,
#  123,
#  11,
#  124,
#  4,
#  0,
#  0,
#  545,
#  0,
#  2,
#  1145,
#  20,
#  40,
#  0,
#  539,
#  817,
#  258,
#  3,
#  3,
#  25,
#  2,
#  2,
#  2,
#  514,
#  1718,
#  28,
#  171,
#  41,
#  8,
#  142,
#  1117,
#  10,
#  3,
#  220,
#  447,
#  523,
#  146,
#  40,
#  90,
#  1108,
#  1047,
#  170,
#  368,
#  278,
#  64,
#  44,
#  5476,
#  113,
#  142,
#  281,
#  87,
#  26,
#  7,
#  7,
#  1,
#  0,
#  0,
#  2,
#  1,
#  0,
#  0,
#  266,
#  0,
#  0,
#  174,
#  0,
#  0,
#  121,
#  223,
#  2,
#  1,
#  1,
#  12,
#  24,
#  512,
#  458,
#  167,
#  121,
#  36,
#  1,
#  2,
#  2,
#  3,
#  4,
#  1,
#  17,
#  2,
#  1,
#  5,
#  1,
#  0,
#  0,
#  2,
#  0]

# %%
keyword = "ykvP"
mg.query(keyword)
# Out:
# {'took': 4,
#  'total': 1,
#  'max_score': 426.04236,
#  'hits': [{'_id': '939278',
#    '_score': 426.04236,
#    'entrezgene': '939278',
#    'name': 'spore protein (HGT island)',
#    'symbol': 'ykvP',
#    'taxid': 224308}]}

# %%
search_results
# Out:
# 1

# %%
keyword = "YfhP"
mg.query(keyword)
# Out:
# {'took': 6,
#  'total': 4,
#  'max_score': 413.27167,
#  'hits': [{'_id': '936190',
#    '_score': 413.27167,
#    'entrezgene': '936190',
#    'name': 'putative membrane hydrolase',
#    'symbol': 'yfhP',
#    'taxid': 224308},
#   {'_id': '1254066',
#    '_score': 413.27167,
#    'entrezgene': '1254066',
#    'name': 'Fe-S cluster assembly transcriptional regulator IscR',
#    'symbol': 'yfhP',
#    'taxid': 99287},
#   {'_id': '107885630',
#    '_score': 54.268234,
#    'entrezgene': '107885630',
#    'name': 'uncharacterized protein YfhP-like',
#    'symbol': 'LOC107885630',
#    'taxid': 7029},
#   {'_id': '945279',
#    '_score': 8.232498,
#    'entrezgene': '945279',
#    'name': 'DNA-binding transcriptional dual regulator IscR',
#    'symbol': 'iscR',
#    'taxid': 511145}]}

# %%
t
