# %%
# !pip install bioc

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# %cd drive
# %cd "My Drive"
# %cd "Colab Notebooks"
# # /content/drive/My Drive/Colab Notebooks
# %cd "Dr.Kojima_JOB"
# Out:
# Mounted at /content/drive
# /content/drive
# /content/drive/My Drive
# /content/drive/My Drive/Colab Notebooks
# /content/drive/My Drive/Colab Notebooks/Dr.Kojima_JOB

# %% [markdown]
# # BioCCollectionオブジェクト調査

# %%
import bioc

# bioc.bioc.BioCCollection型
with open("data_original/aimed_bioc.xml", 'r') as fp:
    anem_bioc = bioc.load(fp)

# # bioc.biocxml.decoder.BioCXMLDocumentReader型
# reader = bioc.BioCXMLDocumentReader("data/anem_bioc.xml")

# # bioc.bioc.BioCDocument型
# for document in reader:
#   print(document)
#   print(type(document))

# %%
for key, value in anem_bioc.__dict__.items():
    print(key, ':',type(value))
#     print(key, ':', value,type(value))
# Out:
# infons : <class 'dict'>
# encoding : <class 'str'>
# version : <class 'str'>
# standalone : <class 'bool'>
# source : <class 'str'>
# date : <class 'str'>
# key : <class 'str'>
# documents : <class 'list'>

# %%
# anem_bioc.__str__()

# %%
document = anem_bioc.__dict__["documents"]

# %%
for key, value in document[0].__dict__.items():
    print(key, ':',type(value))
#     print(key, ':', value,type(value))
# Out:
# infons : <class 'dict'>
# annotations : <class 'list'>
# relations : <class 'list'>
# id : <class 'str'>
# passages : <class 'list'>

# %%
type(document[0].__dict__["passages"][0])
# Out:
# bioc.bioc.BioCPassage

# %%
a_BioCPassage_list = document[0].__dict__["passages"]

# %%
for key, value in a_BioCPassage_list[0].__dict__.items():
  print(key, ':', value,type(value))
# Out:
# infons : {} <class 'dict'>
# annotations : [BioCAnnotation[id=T1,text='delta-catenin',infons=[file=ann,type=protein],locations=[BioCLocation[offset=19,length=13]],], BioCAnnotation[id=T3,text='presenilin (PS) 1',infons=[file=ann,type=protein],locations=[BioCLocation[offset=122,length=17]],], BioCAnnotation[id=T2,text='presenilin 1',infons=[file=ann,type=protein],locations=[BioCLocation[offset=66,length=12]],], BioCAnnotation[id=T6,text='PS1',infons=[file=ann,type=protein],locations=[BioCLocation[offset=415,length=3]],], BioCAnnotation[id=T7,text='PS-2',infons=[file=ann,type=protein],locations=[BioCLocation[offset=441,length=4]],], BioCAnnotation[id=T4,text='delta-catenin',infons=[file=ann,type=protein],locations=[BioCLocation[offset=182,length=13]],], BioCAnnotation[id=T5,text='delta-catenin',infons=[file=ann,type=protein],locations=[BioCLocation[offset=313,length=13]],], BioCAnnotation[id=T10,text='PS1',infons=[file=ann,type=protein],locations=[BioCLocation[offset=513,length=3]],], BioCAnnotation[id=T11,text='armadillo-protein',infons=[file=ann,type=protein],locations=[BioCLocation[offset=618,length=17]],], BioCAnnotation[id=T12,text='p0071',infons=[file=ann,type=protein],locations=[BioCLocation[offset=637,length=5]],], BioCAnnotation[id=T8,text='PS1',infons=[file=ann,type=protein],locations=[BioCLocation[offset=474,length=3]],], BioCAnnotation[id=T13,text='PS1',infons=[file=ann,type=protein],locations=[BioCLocation[offset=660,length=3]],], BioCAnnotation[id=T9,text='PS2',infons=[file=ann,type=protein],locations=[BioCLocation[offset=482,length=3]],]] <class 'list'>
# relations : [BioCRelation[id=R4,infons=[relation type=Interaction,file=ann,type=Relation],nodes=[BioCNode[refid=T12,role=Arg1],BioCNode[refid=T13,role=Arg2]],], BioCRelation[id=R2,infons=[relation type=Interaction,file=ann,type=Relation],nodes=[BioCNode[refid=T3,role=Arg1],BioCNode[refid=T4,role=Arg2]],], BioCRelation[id=R3,infons=[relation type=Interaction,file=ann,type=Relation],nodes=[BioCNode[refid=T5,role=Arg1],BioCNode[refid=T6,role=Arg2]],], BioCRelation[id=R1,infons=[relation type=Interaction,file=ann,type=Relation],nodes=[BioCNode[refid=T1,role=Arg1],BioCNode[refid=T2,role=Arg2]],]] <class 'list'>
# offset : 0 <class 'int'>
# text : Isolation of human delta-catenin and its binding specificity with presenilin 1.
# We screened proteins for interaction with presenilin (PS) 1, and cloned the full-length cDNA of human delta-catenin, which encoded 1225 amino acids.
# Yeast two-hybrid assay, GST binding assay and immunoprecipitation demonstrated that delta-catenin interacted with a hydrophilic loop region in the endoproteolytic C-terminal fragment of PS1, but not with that of PS-2.
# These results suggest that PS1 and PS2 partly differ in function.
# PS1 loop fragment containing the pathogenic mutation retained the binding ability.
# We also found another armadillo-protein, p0071, interacted with PS1. <class 'str'>
# sentences : [] <class 'list'>

# %%
a_BioCAnnotation_list = a_BioCPassage_list[0].__dict__["annotations"]
a_BioCRelations_list = a_BioCPassage_list[0].__dict__["relations"]

# %%
for key, value in a_BioCAnnotation_list[0].__dict__.items():
  print(key, ':', value,type(value))
# Out:
# infons : {'file': 'ann', 'type': 'protein'} <class 'dict'>
# locations : [BioCLocation[offset=19,length=13]] <class 'list'>
# id : T1 <class 'str'>
# text : delta-catenin <class 'str'>

# %%
for key, value in a_BioCRelations_list[0].__dict__.items():
  print(key, ':', value,type(value))
# Out:
# infons : {'relation type': 'Interaction', 'file': 'ann', 'type': 'Relation'} <class 'dict'>
# id : R4 <class 'str'>
# nodes : [BioCNode[refid=T12,role=Arg1], BioCNode[refid=T13,role=Arg2]] <class 'list'>

# %%
a_BioCRelations_Nodes = a_BioCRelations_list[0].__dict__["nodes"]

# %%
Nodes_set = set()
for BioCNode in a_BioCRelations_Nodes:
    print(BioCNode.__dict__["refid"])
    Nodes_set.add(BioCNode.__dict__["refid"])
    
Nodes_set

# %% [markdown]
# # データ作成

# %%
import os
import bioc
import itertools
import csv

# %%
files = os.listdir("data_original")

val_name = []
for a_file in files:
  print(a_file)
  with open("data_original/"+a_file, 'r') as fp:
    dynmc_name = a_file.replace(".xml","")
    locals()[dynmc_name] = bioc.load(fp)
    val_name.append(dynmc_name)
# Out:
# aimed_bioc.xml
# bioinfer_bioc.xml
# hprd50_bioc.xml
# iepa_bioc.xml
# lll_bioc.xml

# %%
def get_PairData(filename):
    # bioc.biocxml.decoder.BioCXMLDocumentReader型
    all_data = []
    reader = bioc.BioCXMLDocumentReader("data_original/"+filename+".xml")

    # bioc.bioc.BioCDocument型
    for document in reader:
        document_id = document.__dict__["id"]

        for passage in document.__dict__["passages"]:
            text = passage.__dict__["text"]

            ann_ids_texts = []
            for annotation in passage.__dict__["annotations"]:
                ann_id = annotation.__dict__["id"]
                ann_text = annotation.__dict__["text"]
                ann_ids_texts.append([ann_id,ann_text])

            for pair in itertools.combinations(ann_ids_texts, 2):
                a,b = list(pair)

                row = [document_id,text,a[0],b[0],a[1],b[1],set([a[0],b[0]])]
                all_data.append(row)
                
    return all_data

# %%
def get_RelDataDict(filename):
    # bioc.biocxml.decoder.BioCXMLDocumentReader型
    all_rel_data_dict = dict()
    reader = bioc.BioCXMLDocumentReader("data_original/"+filename+".xml")
    
    for document in reader:
        document_id = document.__dict__["id"]
        document_rels = []

        for passage in document.__dict__["passages"]:

            for relations in passage.__dict__["relations"]:
                a_node = set()
                for nodes in relations.__dict__["nodes"]:
                    a_node.add(nodes.__dict__["refid"])
                document_rels.append(a_node)

        all_rel_data_dict[document_id] = document_rels
    return all_rel_data_dict

# %%
# filename = "aimed_bioc.xml"

# PairData = get_PairData(filename)
# RelDataDict = get_RelDataDict(filename)

# %%
def Create_CSV(filename):
    PairData = get_PairData(filename)
    RelDataDict = get_RelDataDict(filename)
    
    newPairData = []
    for pair in PairData:
        TorF = "FALSE"
        if pair[-1] in RelDataDict[pair[0]]:
            TorF = "TRUE"
        newPairData.append(pair[:-1]+[TorF])
        
    with open("data/"+filename+".csv", "w") as f:
        writer = csv.writer(f, lineterminator='\n')
        writer.writerows(newPairData)

# %%
Create_CSV("lll_bioc")

# %%
for filename in val_name:
    print(filename)
    Create_CSV(filename)
# Out:
# aimed_bioc
# bioinfer_bioc
# hprd50_bioc
# iepa_bioc
# lll_bioc

# %%
with open('data/lll_bioc.csv') as f:
    reader = csv.reader(f)
    l = [row for row in reader if row != []]
# Out:
#   File "<ipython-input-9-b13ef1f1b4ca>", line 3
#     l = [row if row != []: else: pass for row in reader]
#                          ^
# SyntaxError: invalid syntax

# %%
l
# Out:
# [['LLL_d7',
#   'Expression of the sigma(K)-dependent cwlH gene depended on gerE.',
#   'T1',
#   'T3',
#   'sigma(K)',
#   'cwlH',
#   'TRUE'],
#  [],
#  ['LLL_d7',
#   'Expression of the sigma(K)-dependent cwlH gene depended on gerE.',
#   'T1',
#   'T2',
#   'sigma(K)',
#   'gerE',
#   'FALSE'],
#  [],
#  ['LLL_d7',
#   'Expression of the sigma(K)-dependent cwlH gene depended on gerE.',
#   'T3',
#   'T2',
#   'cwlH',
#   'gerE',
#   'TRUE'],
#  [],
#  ['LLL_d0',
#   'In vivo studies of the activity of four of the kinases, KinA, KinC, KinD (ykvD) and KinE (ykrQ), using abrB transcription as an indicator of Spo0A~P level, revealed that KinC and KinD were responsible for Spo0A~P production during the exponential phase of growth in the absence of KinA and KinB.',
#   'T1',
#   'T3',
#   'KinC',
#   'Spo0A~P',
#   'TRUE'],
#  [],
#  ['LLL_d0',
#   'In vivo studies of the activity of four of the kinases, KinA, KinC, KinD (ykvD) and KinE (ykrQ), using abrB transcription as an indicator of Spo0A~P level, revealed that KinC and KinD were responsible for Spo0A~P production during the exponential phase of growth in the absence of KinA and KinB.',
#   'T1',
#   'T2',
#   'KinC',
#   'KinD',
#   'FALSE'],
#  [],
#  ['LLL_d0',
#   'In vivo studies of the activity of four of the kinases, KinA, KinC, KinD (ykvD) and KinE (ykrQ), using abrB transcription as an indicator of Spo0A~P level, revealed that KinC and KinD were responsible for Spo0A~P production during the exponential phase of growth in the absence of KinA and KinB.',
#   'T3',
#   'T2',
#   'Spo0A~P',
#   'KinD',
#   'TRUE'],
#  [],
#  ['LLL_d9',
#   'Taken together, the results support the idea that sequestration of SpoIIE protein into the prespore plays an important role in the control of sigmaF activation and in coupling this activation to septation.\nsigmaF is controlled by a regulatory cascade involving an anti-sigma factor, SpoIIAB, an anti-anti-sigma factor, SpoIIAA, and a membrane-bound phosphatase, SpoIIE, which converts the inactive, phosphorylated form of SpoIIAA back to the active form.',
#   'T6',
#   'T7',
#   'sigmaF',
#   'SpoIIAA',
#   'FALSE'],
#  [],
#  ['LLL_d9',
#   'Taken together, the results support the idea that sequestration of SpoIIE protein into the prespore plays an important role in the control of sigmaF activation and in coupling this activation to septation.\nsigmaF is controlled by a regulatory cascade involving an anti-sigma factor, SpoIIAB, an anti-anti-sigma factor, SpoIIAA, and a membrane-bound phosphatase, SpoIIE, which converts the inactive, phosphorylated form of SpoIIAA back to the active form.',
#   'T6',
#   'T4',
#   'sigmaF',
#   'SpoIIAA',
#   'TRUE'],
#  [],
#  ['LLL_d9',
#   'Taken together, the results support the idea that sequestration of SpoIIE protein into the prespore plays an important role in the control of sigmaF activation and in coupling this activation to septation.\nsigmaF is controlled by a regulatory cascade involving an anti-sigma factor, SpoIIAB, an anti-anti-sigma factor, SpoIIAA, and a membrane-bound phosphatase, SpoIIE, which converts the inactive, phosphorylated form of SpoIIAA back to the active form.',
#   'T6',
#   'T5',
#   'sigmaF',
#   'SpoIIE',
#   'TRUE'],
#  [],
#  ['LLL_d9',
#   'Taken together, the results support the idea that sequestration of SpoIIE protein into the prespore plays an important role in the control of sigmaF activation and in coupling this activation to septation.\nsigmaF is controlled by a regulatory cascade involving an anti-sigma factor, SpoIIAB, an anti-anti-sigma factor, SpoIIAA, and a membrane-bound phosphatase, SpoIIE, which converts the inactive, phosphorylated form of SpoIIAA back to the active form.',
#   'T6',
#   'T1',
#   'sigmaF',
#   'SpoIIE',
#   'FALSE'],
#  [],
#  ['LLL_d9',
#   'Taken together, the results support the idea that sequestration of SpoIIE protein into the prespore plays an important role in the control of sigmaF activation and in coupling this activation to septation.\nsigmaF is controlled by a regulatory cascade involving an anti-sigma factor, SpoIIAB, an anti-anti-sigma factor, SpoIIAA, and a membrane-bound phosphatase, SpoIIE, which converts the inactive, phosphorylated form of SpoIIAA back to the active form.',
#   'T6',
#   'T3',
#   'sigmaF',
#   'SpoIIAB',
#   'TRUE'],
#  [],
#  ['LLL_d9',
#   'Taken together, the results support the idea that sequestration of SpoIIE protein into the prespore plays an important role in the control of sigmaF activation and in coupling this activation to septation.\nsigmaF is controlled by a regulatory cascade involving an anti-sigma factor, SpoIIAB, an anti-anti-sigma factor, SpoIIAA, and a membrane-bound phosphatase, SpoIIE, which converts the inactive, phosphorylated form of SpoIIAA back to the active form.',
#   'T6',
#   'T2',
#   'sigmaF',
#   'sigmaF',
#   'FALSE'],
#  [],
#  ['LLL_d9',
#   'Taken together, the results support the idea that sequestration of SpoIIE protein into the prespore plays an important role in the control of sigmaF activation and in coupling this activation to septation.\nsigmaF is controlled by a regulatory cascade involving an anti-sigma factor, SpoIIAB, an anti-anti-sigma factor, SpoIIAA, and a membrane-bound phosphatase, SpoIIE, which converts the inactive, phosphorylated form of SpoIIAA back to the active form.',
#   'T7',
#   'T4',
#   'SpoIIAA',
#   'SpoIIAA',
#   'FALSE'],
#  [],
#  ['LLL_d9',
#   'Taken together, the results support the idea that sequestration of SpoIIE protein into the prespore plays an important role in the control of sigmaF activation and in coupling this activation to septation.\nsigmaF is controlled by a regulatory cascade involving an anti-sigma factor, SpoIIAB, an anti-anti-sigma factor, SpoIIAA, and a membrane-bound phosphatase, SpoIIE, which converts the inactive, phosphorylated form of SpoIIAA back to the active form.',
#   'T7',
#   'T5',
#   'SpoIIAA',
#   'SpoIIE',
#   'TRUE'],
#  [],
#  ['LLL_d9',
#   'Taken together, the results support the idea that sequestration of SpoIIE protein into the prespore plays an important role in the control of sigmaF activation and in coupling this activation to septation.\nsigmaF is controlled by a regulatory cascade involving an anti-sigma factor, SpoIIAB, an anti-anti-sigma factor, SpoIIAA, and a membrane-bound phosphatase, SpoIIE, which converts the inactive, phosphorylated form of SpoIIAA back to the active form.',
#   'T7',
#   'T1',
#   'SpoIIAA',
#   'SpoIIE',
#   'FALSE'],
#  [],
#  ['LLL_d9',
#   'Taken together, the results support the idea that sequestration of SpoIIE protein into the prespore plays an important role in the control of sigmaF activation and in coupling this activation to septation.\nsigmaF is controlled by a regulatory cascade involving an anti-sigma factor, SpoIIAB, an anti-anti-sigma factor, SpoIIAA, and a membrane-bound phosphatase, SpoIIE, which converts the inactive, phosphorylated form of SpoIIAA back to the active form.',
#   'T7',
#   'T3',
#   'SpoIIAA',
#   'SpoIIAB',
#   'FALSE'],
#  [],
#  ['LLL_d9',
#   'Taken together, the results support the idea that sequestration of SpoIIE protein into the prespore plays an important role in the control of sigmaF activation and in coupling this activation to septation.\nsigmaF is controlled by a regulatory cascade involving an anti-sigma factor, SpoIIAB, an anti-anti-sigma factor, SpoIIAA, and a membrane-bound phosphatase, SpoIIE, which converts the inactive, phosphorylated form of SpoIIAA back to the active form.',
#   'T7',
#   'T2',
#   'SpoIIAA',
#   'sigmaF',
#   'FALSE'],
#  [],
#  ['LLL_d9',
#   'Taken together, the results support the idea that sequestration of SpoIIE protein into the prespore plays an important role in the control of sigmaF activation and in coupling this activation to septation.\nsigmaF is controlled by a regulatory cascade involving an anti-sigma factor, SpoIIAB, an anti-anti-sigma factor, SpoIIAA, and a membrane-bound phosphatase, SpoIIE, which converts the inactive, phosphorylated form of SpoIIAA back to the active form.',
#   'T4',
#   'T5',
#   'SpoIIAA',
#   'SpoIIE',
#   'FALSE'],
#  [],
#  ['LLL_d9',
#   'Taken together, the results support the idea that sequestration of SpoIIE protein into the prespore plays an important role in the control of sigmaF activation and in coupling this activation to septation.\nsigmaF is controlled by a regulatory cascade involving an anti-sigma factor, SpoIIAB, an anti-anti-sigma factor, SpoIIAA, and a membrane-bound phosphatase, SpoIIE, which converts the inactive, phosphorylated form of SpoIIAA back to the active form.',
#   'T4',
#   'T1',
#   'SpoIIAA',
#   'SpoIIE',
#   'FALSE'],
#  [],
#  ['LLL_d9',
#   'Taken together, the results support the idea that sequestration of SpoIIE protein into the prespore plays an important role in the control of sigmaF activation and in coupling this activation to septation.\nsigmaF is controlled by a regulatory cascade involving an anti-sigma factor, SpoIIAB, an anti-anti-sigma factor, SpoIIAA, and a membrane-bound phosphatase, SpoIIE, which converts the inactive, phosphorylated form of SpoIIAA back to the active form.',
#   'T4',
#   'T3',
#   'SpoIIAA',
#   'SpoIIAB',
#   'FALSE'],
#  [],
#  ['LLL_d9',
#   'Taken together, the results support the idea that sequestration of SpoIIE protein into the prespore plays an important role in the control of sigmaF activation and in coupling this activation to septation.\nsigmaF is controlled by a regulatory cascade involving an anti-sigma factor, SpoIIAB, an anti-anti-sigma factor, SpoIIAA, and a membrane-bound phosphatase, SpoIIE, which converts the inactive, phosphorylated form of SpoIIAA back to the active form.',
#   'T4',
#   'T2',
#   'SpoIIAA',
#   'sigmaF',
#   'FALSE'],
#  [],
#  ['LLL_d9',
#   'Taken together, the results support the idea that sequestration of SpoIIE protein into the prespore plays an important role in the control of sigmaF activation and in coupling this activation to septation.\nsigmaF is controlled by a regulatory cascade involving an anti-sigma factor, SpoIIAB, an anti-anti-sigma factor, SpoIIAA, and a membrane-bound phosphatase, SpoIIE, which converts the inactive, phosphorylated form of SpoIIAA back to the active form.',
#   'T5',
#   'T1',
#   'SpoIIE',
#   'SpoIIE',
#   'FALSE'],
#  [],
#  ['LLL_d9',
#   'Taken together, the results support the idea that sequestration of SpoIIE protein into the prespore plays an important role in the control of sigmaF activation and in coupling this activation to septation.\nsigmaF is controlled by a regulatory cascade involving an anti-sigma factor, SpoIIAB, an anti-anti-sigma factor, SpoIIAA, and a membrane-bound phosphatase, SpoIIE, which converts the inactive, phosphorylated form of SpoIIAA back to the active form.',
#   'T5',
#   'T3',
#   'SpoIIE',
#   'SpoIIAB',
#   'FALSE'],
#  [],
#  ['LLL_d9',
#   'Taken together, the results support the idea that sequestration of SpoIIE protein into the prespore plays an important role in the control of sigmaF activation and in coupling this activation to septation.\nsigmaF is controlled by a regulatory cascade involving an anti-sigma factor, SpoIIAB, an anti-anti-sigma factor, SpoIIAA, and a membrane-bound phosphatase, SpoIIE, which converts the inactive, phosphorylated form of SpoIIAA back to the active form.',
#   'T5',
#   'T2',
#   'SpoIIE',
#   'sigmaF',
#   'FALSE'],
#  [],
#  ['LLL_d9',
#   'Taken together, the results support the idea that sequestration of SpoIIE protein into the prespore plays an important role in the control of sigmaF activation and in coupling this activation to septation.\nsigmaF is controlled by a regulatory cascade involving an anti-sigma factor, SpoIIAB, an anti-anti-sigma factor, SpoIIAA, and a membrane-bound phosphatase, SpoIIE, which converts the inactive, phosphorylated form of SpoIIAA back to the active form.',
#   'T1',
#   'T3',
#   'SpoIIE',
#   'SpoIIAB',
#   'FALSE'],
#  [],
#  ['LLL_d9',
#   'Taken together, the results support the idea that sequestration of SpoIIE protein into the prespore plays an important role in the control of sigmaF activation and in coupling this activation to septation.\nsigmaF is controlled by a regulatory cascade involving an anti-sigma factor, SpoIIAB, an anti-anti-sigma factor, SpoIIAA, and a membrane-bound phosphatase, SpoIIE, which converts the inactive, phosphorylated form of SpoIIAA back to the active form.',
#   'T1',
#   'T2',
#   'SpoIIE',
#   'sigmaF',
#   'TRUE'],
#  [],
#  ['LLL_d9',
#   'Taken together, the results support the idea that sequestration of SpoIIE protein into the prespore plays an important role in the control of sigmaF activation and in coupling this activation to septation.\nsigmaF is controlled by a regulatory cascade involving an anti-sigma factor, SpoIIAB, an anti-anti-sigma factor, SpoIIAA, and a membrane-bound phosphatase, SpoIIE, which converts the inactive, phosphorylated form of SpoIIAA back to the active form.',
#   'T3',
#   'T2',
#   'SpoIIAB',
#   'sigmaF',
#   'FALSE'],
#  [],
#  ['LLL_d40',
#   'Although spo0H is transcriptionally regulated by the key regulatory device that controls sporulation initiation, the Spo0 phosphorelay, there is considerable evidence implicating a mechanism of post-translational control that governs the activity and concentration of sigmaH.',
#   'T1',
#   'T2',
#   'Spo0',
#   'spo0H',
#   'TRUE'],
#  [],
#  ['LLL_d35',
#   'The Bacillus subtilis clpC operon is regulated by two stress induction pathways relying on either sigmaB or a class III stress induction mechanism acting at a sigmaA-like promoter.\nOur data demonstrate that the CtsR protein acts as a global repressor of the clpC operon, as well as other class III heat shock genes, by preventing unstressed transcription from either the sigmaB- or sigmaA-dependent promoter and might be inactivated or dissociate under inducing stress conditions.',
#   'T6',
#   'T7',
#   'sigmaA',
#   'clpC',
#   'TRUE'],
#  [],
#  ['LLL_d35',
#   'The Bacillus subtilis clpC operon is regulated by two stress induction pathways relying on either sigmaB or a class III stress induction mechanism acting at a sigmaA-like promoter.\nOur data demonstrate that the CtsR protein acts as a global repressor of the clpC operon, as well as other class III heat shock genes, by preventing unstressed transcription from either the sigmaB- or sigmaA-dependent promoter and might be inactivated or dissociate under inducing stress conditions.',
#   'T6',
#   'T4',
#   'sigmaA',
#   'CtsR',
#   'FALSE'],
#  [],
#  ['LLL_d35',
#   'The Bacillus subtilis clpC operon is regulated by two stress induction pathways relying on either sigmaB or a class III stress induction mechanism acting at a sigmaA-like promoter.\nOur data demonstrate that the CtsR protein acts as a global repressor of the clpC operon, as well as other class III heat shock genes, by preventing unstressed transcription from either the sigmaB- or sigmaA-dependent promoter and might be inactivated or dissociate under inducing stress conditions.',
#   'T6',
#   'T5',
#   'sigmaA',
#   'sigmaB',
#   'FALSE'],
#  [],
#  ['LLL_d35',
#   'The Bacillus subtilis clpC operon is regulated by two stress induction pathways relying on either sigmaB or a class III stress induction mechanism acting at a sigmaA-like promoter.\nOur data demonstrate that the CtsR protein acts as a global repressor of the clpC operon, as well as other class III heat shock genes, by preventing unstressed transcription from either the sigmaB- or sigmaA-dependent promoter and might be inactivated or dissociate under inducing stress conditions.',
#   'T6',
#   'T1',
#   'sigmaA',
#   'sigmaB',
#   'FALSE'],
#  [],
#  ['LLL_d35',
#   'The Bacillus subtilis clpC operon is regulated by two stress induction pathways relying on either sigmaB or a class III stress induction mechanism acting at a sigmaA-like promoter.\nOur data demonstrate that the CtsR protein acts as a global repressor of the clpC operon, as well as other class III heat shock genes, by preventing unstressed transcription from either the sigmaB- or sigmaA-dependent promoter and might be inactivated or dissociate under inducing stress conditions.',
#   'T6',
#   'T3',
#   'sigmaA',
#   'clpC',
#   'FALSE'],
#  [],
#  ['LLL_d35',
#   'The Bacillus subtilis clpC operon is regulated by two stress induction pathways relying on either sigmaB or a class III stress induction mechanism acting at a sigmaA-like promoter.\nOur data demonstrate that the CtsR protein acts as a global repressor of the clpC operon, as well as other class III heat shock genes, by preventing unstressed transcription from either the sigmaB- or sigmaA-dependent promoter and might be inactivated or dissociate under inducing stress conditions.',
#   'T6',
#   'T2',
#   'sigmaA',
#   'sigmaA',
#   'FALSE'],
#  [],
#  ['LLL_d35',
#   'The Bacillus subtilis clpC operon is regulated by two stress induction pathways relying on either sigmaB or a class III stress induction mechanism acting at a sigmaA-like promoter.\nOur data demonstrate that the CtsR protein acts as a global repressor of the clpC operon, as well as other class III heat shock genes, by preventing unstressed transcription from either the sigmaB- or sigmaA-dependent promoter and might be inactivated or dissociate under inducing stress conditions.',
#   'T7',
#   'T4',
#   'clpC',
#   'CtsR',
#   'TRUE'],
#  [],
#  ['LLL_d35',
#   'The Bacillus subtilis clpC operon is regulated by two stress induction pathways relying on either sigmaB or a class III stress induction mechanism acting at a sigmaA-like promoter.\nOur data demonstrate that the CtsR protein acts as a global repressor of the clpC operon, as well as other class III heat shock genes, by preventing unstressed transcription from either the sigmaB- or sigmaA-dependent promoter and might be inactivated or dissociate under inducing stress conditions.',
#   'T7',
#   'T5',
#   'clpC',
#   'sigmaB',
#   'TRUE'],
#  [],
#  ['LLL_d35',
#   'The Bacillus subtilis clpC operon is regulated by two stress induction pathways relying on either sigmaB or a class III stress induction mechanism acting at a sigmaA-like promoter.\nOur data demonstrate that the CtsR protein acts as a global repressor of the clpC operon, as well as other class III heat shock genes, by preventing unstressed transcription from either the sigmaB- or sigmaA-dependent promoter and might be inactivated or dissociate under inducing stress conditions.',
#   'T7',
#   'T1',
#   'clpC',
#   'sigmaB',
#   'FALSE'],
#  [],
#  ['LLL_d35',
#   'The Bacillus subtilis clpC operon is regulated by two stress induction pathways relying on either sigmaB or a class III stress induction mechanism acting at a sigmaA-like promoter.\nOur data demonstrate that the CtsR protein acts as a global repressor of the clpC operon, as well as other class III heat shock genes, by preventing unstressed transcription from either the sigmaB- or sigmaA-dependent promoter and might be inactivated or dissociate under inducing stress conditions.',
#   'T7',
#   'T3',
#   'clpC',
#   'clpC',
#   'FALSE'],
#  [],
#  ['LLL_d35',
#   'The Bacillus subtilis clpC operon is regulated by two stress induction pathways relying on either sigmaB or a class III stress induction mechanism acting at a sigmaA-like promoter.\nOur data demonstrate that the CtsR protein acts as a global repressor of the clpC operon, as well as other class III heat shock genes, by preventing unstressed transcription from either the sigmaB- or sigmaA-dependent promoter and might be inactivated or dissociate under inducing stress conditions.',
#   'T7',
#   'T2',
#   'clpC',
#   'sigmaA',
#   'FALSE'],
#  [],
#  ['LLL_d35',
#   'The Bacillus subtilis clpC operon is regulated by two stress induction pathways relying on either sigmaB or a class III stress induction mechanism acting at a sigmaA-like promoter.\nOur data demonstrate that the CtsR protein acts as a global repressor of the clpC operon, as well as other class III heat shock genes, by preventing unstressed transcription from either the sigmaB- or sigmaA-dependent promoter and might be inactivated or dissociate under inducing stress conditions.',
#   'T4',
#   'T5',
#   'CtsR',
#   'sigmaB',
#   'FALSE'],
#  [],
#  ['LLL_d35',
#   'The Bacillus subtilis clpC operon is regulated by two stress induction pathways relying on either sigmaB or a class III stress induction mechanism acting at a sigmaA-like promoter.\nOur data demonstrate that the CtsR protein acts as a global repressor of the clpC operon, as well as other class III heat shock genes, by preventing unstressed transcription from either the sigmaB- or sigmaA-dependent promoter and might be inactivated or dissociate under inducing stress conditions.',
#   'T4',
#   'T1',
#   'CtsR',
#   'sigmaB',
#   'FALSE'],
#  [],
#  ['LLL_d35',
#   'The Bacillus subtilis clpC operon is regulated by two stress induction pathways relying on either sigmaB or a class III stress induction mechanism acting at a sigmaA-like promoter.\nOur data demonstrate that the CtsR protein acts as a global repressor of the clpC operon, as well as other class III heat shock genes, by preventing unstressed transcription from either the sigmaB- or sigmaA-dependent promoter and might be inactivated or dissociate under inducing stress conditions.',
#   'T4',
#   'T3',
#   'CtsR',
#   'clpC',
#   'FALSE'],
#  [],
#  ['LLL_d35',
#   'The Bacillus subtilis clpC operon is regulated by two stress induction pathways relying on either sigmaB or a class III stress induction mechanism acting at a sigmaA-like promoter.\nOur data demonstrate that the CtsR protein acts as a global repressor of the clpC operon, as well as other class III heat shock genes, by preventing unstressed transcription from either the sigmaB- or sigmaA-dependent promoter and might be inactivated or dissociate under inducing stress conditions.',
#   'T4',
#   'T2',
#   'CtsR',
#   'sigmaA',
#   'FALSE'],
#  [],
#  ['LLL_d35',
#   'The Bacillus subtilis clpC operon is regulated by two stress induction pathways relying on either sigmaB or a class III stress induction mechanism acting at a sigmaA-like promoter.\nOur data demonstrate that the CtsR protein acts as a global repressor of the clpC operon, as well as other class III heat shock genes, by preventing unstressed transcription from either the sigmaB- or sigmaA-dependent promoter and might be inactivated or dissociate under inducing stress conditions.',
#   'T5',
#   'T1',
#   'sigmaB',
#   'sigmaB',
#   'FALSE'],
#  [],
#  ['LLL_d35',
#   'The Bacillus subtilis clpC operon is regulated by two stress induction pathways relying on either sigmaB or a class III stress induction mechanism acting at a sigmaA-like promoter.\nOur data demonstrate that the CtsR protein acts as a global repressor of the clpC operon, as well as other class III heat shock genes, by preventing unstressed transcription from either the sigmaB- or sigmaA-dependent promoter and might be inactivated or dissociate under inducing stress conditions.',
#   'T5',
#   'T3',
#   'sigmaB',
#   'clpC',
#   'FALSE'],
#  [],
#  ['LLL_d35',
#   'The Bacillus subtilis clpC operon is regulated by two stress induction pathways relying on either sigmaB or a class III stress induction mechanism acting at a sigmaA-like promoter.\nOur data demonstrate that the CtsR protein acts as a global repressor of the clpC operon, as well as other class III heat shock genes, by preventing unstressed transcription from either the sigmaB- or sigmaA-dependent promoter and might be inactivated or dissociate under inducing stress conditions.',
#   'T5',
#   'T2',
#   'sigmaB',
#   'sigmaA',
#   'FALSE'],
#  [],
#  ['LLL_d35',
#   'The Bacillus subtilis clpC operon is regulated by two stress induction pathways relying on either sigmaB or a class III stress induction mechanism acting at a sigmaA-like promoter.\nOur data demonstrate that the CtsR protein acts as a global repressor of the clpC operon, as well as other class III heat shock genes, by preventing unstressed transcription from either the sigmaB- or sigmaA-dependent promoter and might be inactivated or dissociate under inducing stress conditions.',
#   'T1',
#   'T3',
#   'sigmaB',
#   'clpC',
#   'TRUE'],
#  [],
#  ['LLL_d35',
#   'The Bacillus subtilis clpC operon is regulated by two stress induction pathways relying on either sigmaB or a class III stress induction mechanism acting at a sigmaA-like promoter.\nOur data demonstrate that the CtsR protein acts as a global repressor of the clpC operon, as well as other class III heat shock genes, by preventing unstressed transcription from either the sigmaB- or sigmaA-dependent promoter and might be inactivated or dissociate under inducing stress conditions.',
#   'T1',
#   'T2',
#   'sigmaB',
#   'sigmaA',
#   'FALSE'],
#  [],
#  ['LLL_d35',
#   'The Bacillus subtilis clpC operon is regulated by two stress induction pathways relying on either sigmaB or a class III stress induction mechanism acting at a sigmaA-like promoter.\nOur data demonstrate that the CtsR protein acts as a global repressor of the clpC operon, as well as other class III heat shock genes, by preventing unstressed transcription from either the sigmaB- or sigmaA-dependent promoter and might be inactivated or dissociate under inducing stress conditions.',
#   'T3',
#   'T2',
#   'clpC',
#   'sigmaA',
#   'TRUE'],
#  [],
#  ['LLL_d32',
#   'Transcriptional studies demonstrated that the expression from the araE promoter is induced by L-arabinose, repressed by glucose, and negatively regulated by AraR.',
#   'T1',
#   'T2',
#   'AraR',
#   'araE',
#   'TRUE'],
#  [],
#  ['LLL_d23',
#   'Transcriptional studies showed that nadE is strongly induced in response to heat, ethanol and salt stress or after starvation for glucose in a sigma B-dependent manner.',
#   'T1',
#   'T2',
#   'sigma B',
#   'nadE',
#   'TRUE'],
#  [],
#  ['LLL_d24',
#   'Furthermore, YtxH and YvyD seemed to be induced after phosphate starvation in the wild type in a sigma(B)-dependent manner and in the sigB mutant probably via sigma(H).',
#   'T4',
#   'T1',
#   'YvyD',
#   'sigma(B)',
#   'TRUE'],
#  [],
#  ['LLL_d24',
#   'Furthermore, YtxH and YvyD seemed to be induced after phosphate starvation in the wild type in a sigma(B)-dependent manner and in the sigB mutant probably via sigma(H).',
#   'T4',
#   'T3',
#   'YvyD',
#   'YtxH',
#   'FALSE'],
#  [],
#  ['LLL_d24',
#   'Furthermore, YtxH and YvyD seemed to be induced after phosphate starvation in the wild type in a sigma(B)-dependent manner and in the sigB mutant probably via sigma(H).',
#   'T4',
#   'T2',
#   'YvyD',
#   'sigma(H)',
#   'TRUE'],
#  [],
#  ['LLL_d24',
#   'Furthermore, YtxH and YvyD seemed to be induced after phosphate starvation in the wild type in a sigma(B)-dependent manner and in the sigB mutant probably via sigma(H).',
#   'T1',
#   'T3',
#   'sigma(B)',
#   'YtxH',
#   'TRUE'],
#  [],
#  ['LLL_d24',
#   'Furthermore, YtxH and YvyD seemed to be induced after phosphate starvation in the wild type in a sigma(B)-dependent manner and in the sigB mutant probably via sigma(H).',
#   'T1',
#   'T2',
#   'sigma(B)',
#   'sigma(H)',
#   'FALSE'],
#  [],
#  ['LLL_d24',
#   'Furthermore, YtxH and YvyD seemed to be induced after phosphate starvation in the wild type in a sigma(B)-dependent manner and in the sigB mutant probably via sigma(H).',
#   'T3',
#   'T2',
#   'YtxH',
#   'sigma(H)',
#   'TRUE'],
#  [],
#  ['LLL_d18',
#   'Most cot genes, and the gerE gene, are transcribed by sigmaK RNA polymerase.\nPreviously, it was shown that the GerE protein inhibits transcription in vitro of the sigK gene encoding sigmaK.\nThese results demonstrate that sigmaK-dependent transcription of gerE initiates a negative feedback loop in which GerE acts as a repressor to limit production of sigmaK.\nA low level of GerE activated transcription of cotD by sigmaK RNA polymerase in vitro, but a higher level of GerE repressed cotD transcription.\nHere, we show that GerE binds near the sigK transcriptional start site, to act as a repressor.\nWe show that GerE binds to two sites that span the -35 region of the cotD promoter.\nThese results suggest that a rising level of GerE in sporulating cells may first activate cotD transcription from the upstream site then repress transcription as the downstream site becomes occupied.',
#   'T1',
#   'T3',
#   'sigmaK',
#   'gerE',
#   'TRUE'],
#  [],
#  ['LLL_d18',
#   'Most cot genes, and the gerE gene, are transcribed by sigmaK RNA polymerase.\nPreviously, it was shown that the GerE protein inhibits transcription in vitro of the sigK gene encoding sigmaK.\nThese results demonstrate that sigmaK-dependent transcription of gerE initiates a negative feedback loop in which GerE acts as a repressor to limit production of sigmaK.\nA low level of GerE activated transcription of cotD by sigmaK RNA polymerase in vitro, but a higher level of GerE repressed cotD transcription.\nHere, we show that GerE binds near the sigK transcriptional start site, to act as a repressor.\nWe show that GerE binds to two sites that span the -35 region of the cotD promoter.\nThese results suggest that a rising level of GerE in sporulating cells may first activate cotD transcription from the upstream site then repress transcription as the downstream site becomes occupied.',
#   'T1',
#   'T2',
#   'sigmaK',
#   'cot',
#   'TRUE'],
#  [],
#  ['LLL_d18',
#   'Most cot genes, and the gerE gene, are transcribed by sigmaK RNA polymerase.\nPreviously, it was shown that the GerE protein inhibits transcription in vitro of the sigK gene encoding sigmaK.\nThese results demonstrate that sigmaK-dependent transcription of gerE initiates a negative feedback loop in which GerE acts as a repressor to limit production of sigmaK.\nA low level of GerE activated transcription of cotD by sigmaK RNA polymerase in vitro, but a higher level of GerE repressed cotD transcription.\nHere, we show that GerE binds near the sigK transcriptional start site, to act as a repressor.\nWe show that GerE binds to two sites that span the -35 region of the cotD promoter.\nThese results suggest that a rising level of GerE in sporulating cells may first activate cotD transcription from the upstream site then repress transcription as the downstream site becomes occupied.',
#   'T1',
#   'T6',
#   'sigmaK',
#   'sigmaK',
#   'FALSE'],
#  [],
#  ['LLL_d18',
#   'Most cot genes, and the gerE gene, are transcribed by sigmaK RNA polymerase.\nPreviously, it was shown that the GerE protein inhibits transcription in vitro of the sigK gene encoding sigmaK.\nThese results demonstrate that sigmaK-dependent transcription of gerE initiates a negative feedback loop in which GerE acts as a repressor to limit production of sigmaK.\nA low level of GerE activated transcription of cotD by sigmaK RNA polymerase in vitro, but a higher level of GerE repressed cotD transcription.\nHere, we show that GerE binds near the sigK transcriptional start site, to act as a repressor.\nWe show that GerE binds to two sites that span the -35 region of the cotD promoter.\nThese results suggest that a rising level of GerE in sporulating cells may first activate cotD transcription from the upstream site then repress transcription as the downstream site becomes occupied.',
#   'T1',
#   'T7',
#   'sigmaK',
#   'GerE',
#   'FALSE'],
#  [],
#  ['LLL_d18',
#   'Most cot genes, and the gerE gene, are transcribed by sigmaK RNA polymerase.\nPreviously, it was shown that the GerE protein inhibits transcription in vitro of the sigK gene encoding sigmaK.\nThese results demonstrate that sigmaK-dependent transcription of gerE initiates a negative feedback loop in which GerE acts as a repressor to limit production of sigmaK.\nA low level of GerE activated transcription of cotD by sigmaK RNA polymerase in vitro, but a higher level of GerE repressed cotD transcription.\nHere, we show that GerE binds near the sigK transcriptional start site, to act as a repressor.\nWe show that GerE binds to two sites that span the -35 region of the cotD promoter.\nThese results suggest that a rising level of GerE in sporulating cells may first activate cotD transcription from the upstream site then repress transcription as the downstream site becomes occupied.',
#   'T1',
#   'T4',
#   'sigmaK',
#   'GerE',
#   'FALSE'],
#  [],
#  ['LLL_d18',
#   'Most cot genes, and the gerE gene, are transcribed by sigmaK RNA polymerase.\nPreviously, it was shown that the GerE protein inhibits transcription in vitro of the sigK gene encoding sigmaK.\nThese results demonstrate that sigmaK-dependent transcription of gerE initiates a negative feedback loop in which GerE acts as a repressor to limit production of sigmaK.\nA low level of GerE activated transcription of cotD by sigmaK RNA polymerase in vitro, but a higher level of GerE repressed cotD transcription.\nHere, we show that GerE binds near the sigK transcriptional start site, to act as a repressor.\nWe show that GerE binds to two sites that span the -35 region of the cotD promoter.\nThese results suggest that a rising level of GerE in sporulating cells may first activate cotD transcription from the upstream site then repress transcription as the downstream site becomes occupied.',
#   'T1',
#   'T5',
#   'sigmaK',
#   'sigK',
#   'FALSE'],
#  [],
#  ['LLL_d18',
#   'Most cot genes, and the gerE gene, are transcribed by sigmaK RNA polymerase.\nPreviously, it was shown that the GerE protein inhibits transcription in vitro of the sigK gene encoding sigmaK.\nThese results demonstrate that sigmaK-dependent transcription of gerE initiates a negative feedback loop in which GerE acts as a repressor to limit production of sigmaK.\nA low level of GerE activated transcription of cotD by sigmaK RNA polymerase in vitro, but a higher level of GerE repressed cotD transcription.\nHere, we show that GerE binds near the sigK transcriptional start site, to act as a repressor.\nWe show that GerE binds to two sites that span the -35 region of the cotD promoter.\nThese results suggest that a rising level of GerE in sporulating cells may first activate cotD transcription from the upstream site then repress transcription as the downstream site becomes occupied.',
#   'T1',
#   'T10',
#   'sigmaK',
#   'GerE',
#   'FALSE'],
#  [],
#  ['LLL_d18',
#   'Most cot genes, and the gerE gene, are transcribed by sigmaK RNA polymerase.\nPreviously, it was shown that the GerE protein inhibits transcription in vitro of the sigK gene encoding sigmaK.\nThese results demonstrate that sigmaK-dependent transcription of gerE initiates a negative feedback loop in which GerE acts as a repressor to limit production of sigmaK.\nA low level of GerE activated transcription of cotD by sigmaK RNA polymerase in vitro, but a higher level of GerE repressed cotD transcription.\nHere, we show that GerE binds near the sigK transcriptional start site, to act as a repressor.\nWe show that GerE binds to two sites that span the -35 region of the cotD promoter.\nThese results suggest that a rising level of GerE in sporulating cells may first activate cotD transcription from the upstream site then repress transcription as the downstream site becomes occupied.',
#   'T1',
#   'T11',
#   'sigmaK',
#   'sigmaK',
#   'FALSE'],
#  [],
#  ['LLL_d18',
#   'Most cot genes, and the gerE gene, are transcribed by sigmaK RNA polymerase.\nPreviously, it was shown that the GerE protein inhibits transcription in vitro of the sigK gene encoding sigmaK.\nThese results demonstrate that sigmaK-dependent transcription of gerE initiates a negative feedback loop in which GerE acts as a repressor to limit production of sigmaK.\nA low level of GerE activated transcription of cotD by sigmaK RNA polymerase in vitro, but a higher level of GerE repressed cotD transcription.\nHere, we show that GerE binds near the sigK transcriptional start site, to act as a repressor.\nWe show that GerE binds to two sites that span the -35 region of the cotD promoter.\nThese results suggest that a rising level of GerE in sporulating cells may first activate cotD transcription from the upstream site then repress transcription as the downstream site becomes occupied.',
#   'T1',
#   'T12',
#   'sigmaK',
#   'GerE',
#   'FALSE'],
#  [],
#  ['LLL_d18',
#   'Most cot genes, and the gerE gene, are transcribed by sigmaK RNA polymerase.\nPreviously, it was shown that the GerE protein inhibits transcription in vitro of the sigK gene encoding sigmaK.\nThese results demonstrate that sigmaK-dependent transcription of gerE initiates a negative feedback loop in which GerE acts as a repressor to limit production of sigmaK.\nA low level of GerE activated transcription of cotD by sigmaK RNA polymerase in vitro, but a higher level of GerE repressed cotD transcription.\nHere, we show that GerE binds near the sigK transcriptional start site, to act as a repressor.\nWe show that GerE binds to two sites that span the -35 region of the cotD promoter.\nThese results suggest that a rising level of GerE in sporulating cells may first activate cotD transcription from the upstream site then repress transcription as the downstream site becomes occupied.',
#   'T1',
#   'T8',
#   'sigmaK',
#   'gerE',
#   'FALSE'],
#  [],
#  ['LLL_d18',
#   'Most cot genes, and the gerE gene, are transcribed by sigmaK RNA polymerase.\nPreviously, it was shown that the GerE protein inhibits transcription in vitro of the sigK gene encoding sigmaK.\nThese results demonstrate that sigmaK-dependent transcription of gerE initiates a negative feedback loop in which GerE acts as a repressor to limit production of sigmaK.\nA low level of GerE activated transcription of cotD by sigmaK RNA polymerase in vitro, but a higher level of GerE repressed cotD transcription.\nHere, we show that GerE binds near the sigK transcriptional start site, to act as a repressor.\nWe show that GerE binds to two sites that span the -35 region of the cotD promoter.\nThese results suggest that a rising level of GerE in sporulating cells may first activate cotD transcription from the upstream site then repress transcription as the downstream site becomes occupied.',
#   'T1',
#   'T13',
#   'sigmaK',
#   'cotD',
#   'FALSE'],
#  [],
#  ['LLL_d18',
#   'Most cot genes, and the gerE gene, are transcribed by sigmaK RNA polymerase.\nPreviously, it was shown that the GerE protein inhibits transcription in vitro of the sigK gene encoding sigmaK.\nThese results demonstrate that sigmaK-dependent transcription of gerE initiates a negative feedback loop in which GerE acts as a repressor to limit production of sigmaK.\nA low level of GerE activated transcription of cotD by sigmaK RNA polymerase in vitro, but a higher level of GerE repressed cotD transcription.\nHere, we show that GerE binds near the sigK transcriptional start site, to act as a repressor.\nWe show that GerE binds to two sites that span the -35 region of the cotD promoter.\nThese results suggest that a rising level of GerE in sporulating cells may first activate cotD transcription from the upstream site then repress transcription as the downstream site becomes occupied.',
#   'T1',
#   'T14',
#   'sigmaK',
#   'cotD',
#   'FALSE'],
#  [],
#  ['LLL_d18',
#   'Most cot genes, and the gerE gene, are transcribed by sigmaK RNA polymerase.\nPreviously, it was shown that the GerE protein inhibits transcription in vitro of the sigK gene encoding sigmaK.\nThese results demonstrate that sigmaK-dependent transcription of gerE initiates a negative feedback loop in which GerE acts as a repressor to limit production of sigmaK.\nA low level of GerE activated transcription of cotD by sigmaK RNA polymerase in vitro, but a higher level of GerE repressed cotD transcription.\nHere, we show that GerE binds near the sigK transcriptional start site, to act as a repressor.\nWe show that GerE binds to two sites that span the -35 region of the cotD promoter.\nThese results suggest that a rising level of GerE in sporulating cells may first activate cotD transcription from the upstream site then repress transcription as the downstream site becomes occupied.',
#   'T1',
#   'T9',
#   'sigmaK',
#   'sigmaK',
#   'FALSE'],
#  [],
#  ['LLL_d18',
#   'Most cot genes, and the gerE gene, are transcribed by sigmaK RNA polymerase.\nPreviously, it was shown that the GerE protein inhibits transcription in vitro of the sigK gene encoding sigmaK.\nThese results demonstrate that sigmaK-dependent transcription of gerE initiates a negative feedback loop in which GerE acts as a repressor to limit production of sigmaK.\nA low level of GerE activated transcription of cotD by sigmaK RNA polymerase in vitro, but a higher level of GerE repressed cotD transcription.\nHere, we show that GerE binds near the sigK transcriptional start site, to act as a repressor.\nWe show that GerE binds to two sites that span the -35 region of the cotD promoter.\nThese results suggest that a rising level of GerE in sporulating cells may first activate cotD transcription from the upstream site then repress transcription as the downstream site becomes occupied.',
#   'T1',
#   'T15',
#   'sigmaK',
#   'GerE',
#   'FALSE'],
#  [],
#  ['LLL_d18',
#   'Most cot genes, and the gerE gene, are transcribed by sigmaK RNA polymerase.\nPreviously, it was shown that the GerE protein inhibits transcription in vitro of the sigK gene encoding sigmaK.\nThese results demonstrate that sigmaK-dependent transcription of gerE initiates a negative feedback loop in which GerE acts as a repressor to limit production of sigmaK.\nA low level of GerE activated transcription of cotD by sigmaK RNA polymerase in vitro, but a higher level of GerE repressed cotD transcription.\nHere, we show that GerE binds near the sigK transcriptional start site, to act as a repressor.\nWe show that GerE binds to two sites that span the -35 region of the cotD promoter.\nThese results suggest that a rising level of GerE in sporulating cells may first activate cotD transcription from the upstream site then repress transcription as the downstream site becomes occupied.',
#   'T1',
#   'T16',
#   'sigmaK',
#   'sigK',
#   'FALSE'],
#  [],
#  ['LLL_d18',
#   'Most cot genes, and the gerE gene, are transcribed by sigmaK RNA polymerase.\nPreviously, it was shown that the GerE protein inhibits transcription in vitro of the sigK gene encoding sigmaK.\nThese results demonstrate that sigmaK-dependent transcription of gerE initiates a negative feedback loop in which GerE acts as a repressor to limit production of sigmaK.\nA low level of GerE activated transcription of cotD by sigmaK RNA polymerase in vitro, but a higher level of GerE repressed cotD transcription.\nHere, we show that GerE binds near the sigK transcriptional start site, to act as a repressor.\nWe show that GerE binds to two sites that span the -35 region of the cotD promoter.\nThese results suggest that a rising level of GerE in sporulating cells may first activate cotD transcription from the upstream site then repress transcription as the downstream site becomes occupied.',
#   'T1',
#   'T17',
#   'sigmaK',
#   'GerE',
#   'FALSE'],
#  [],
#  ['LLL_d18',
#   'Most cot genes, and the gerE gene, are transcribed by sigmaK RNA polymerase.\nPreviously, it was shown that the GerE protein inhibits transcription in vitro of the sigK gene encoding sigmaK.\nThese results demonstrate that sigmaK-dependent transcription of gerE initiates a negative feedback loop in which GerE acts as a repressor to limit production of sigmaK.\nA low level of GerE activated transcription of cotD by sigmaK RNA polymerase in vitro, but a higher level of GerE repressed cotD transcription.\nHere, we show that GerE binds near the sigK transcriptional start site, to act as a repressor.\nWe show that GerE binds to two sites that span the -35 region of the cotD promoter.\nThese results suggest that a rising level of GerE in sporulating cells may first activate cotD transcription from the upstream site then repress transcription as the downstream site becomes occupied.',
#   'T1',
#   'T18',
#   'sigmaK',
#   'cotD',
#   'FALSE'],
#  [],
#  ['LLL_d18',
#   'Most cot genes, and the gerE gene, are transcribed by sigmaK RNA polymerase.\nPreviously, it was shown that the GerE protein inhibits transcription in vitro of the sigK gene encoding sigmaK.\nThese results demonstrate that sigmaK-dependent transcription of gerE initiates a negative feedback loop in which GerE acts as a repressor to limit production of sigmaK.\nA low level of GerE activated transcription of cotD by sigmaK RNA polymerase in vitro, but a higher level of GerE repressed cotD transcription.\nHere, we show that GerE binds near the sigK transcriptional start site, to act as a repressor.\nWe show that GerE binds to two sites that span the -35 region of the cotD promoter.\nThese results suggest that a rising level of GerE in sporulating cells may first activate cotD transcription from the upstream site then repress transcription as the downstream site becomes occupied.',
#   'T1',
#   'T19',
#   'sigmaK',
#   'GerE',
#   'FALSE'],
#  [],
#  ['LLL_d18',
#   'Most cot genes, and the gerE gene, are transcribed by sigmaK RNA polymerase.\nPreviously, it was shown that the GerE protein inhibits transcription in vitro of the sigK gene encoding sigmaK.\nThese results demonstrate that sigmaK-dependent transcription of gerE initiates a negative feedback loop in which GerE acts as a repressor to limit production of sigmaK.\nA low level of GerE activated transcription of cotD by sigmaK RNA polymerase in vitro, but a higher level of GerE repressed cotD transcription.\nHere, we show that GerE binds near the sigK transcriptional start site, to act as a repressor.\nWe show that GerE binds to two sites that span the -35 region of the cotD promoter.\nThese results suggest that a rising level of GerE in sporulating cells may first activate cotD transcription from the upstream site then repress transcription as the downstream site becomes occupied.',
#   'T1',
#   'T20',
#   'sigmaK',
#   'cotD',
#   'FALSE'],
#  [],
#  ['LLL_d18',
#   'Most cot genes, and the gerE gene, are transcribed by sigmaK RNA polymerase.\nPreviously, it was shown that the GerE protein inhibits transcription in vitro of the sigK gene encoding sigmaK.\nThese results demonstrate that sigmaK-dependent transcription of gerE initiates a negative feedback loop in which GerE acts as a repressor to limit production of sigmaK.\nA low level of GerE activated transcription of cotD by sigmaK RNA polymerase in vitro, but a higher level of GerE repressed cotD transcription.\nHere, we show that GerE binds near the sigK transcriptional start site, to act as a repressor.\nWe show that GerE binds to two sites that span the -35 region of the cotD promoter.\nThese results suggest that a rising level of GerE in sporulating cells may first activate cotD transcription from the upstream site then repress transcription as the downstream site becomes occupied.',
#   'T3',
#   'T2',
#   'gerE',
#   'cot',
#   'FALSE'],
#  [],
#  ['LLL_d18',
#   'Most cot genes, and the gerE gene, are transcribed by sigmaK RNA polymerase.\nPreviously, it was shown that the GerE protein inhibits transcription in vitro of the sigK gene encoding sigmaK.\nThese results demonstrate that sigmaK-dependent transcription of gerE initiates a negative feedback loop in which GerE acts as a repressor to limit production of sigmaK.\nA low level of GerE activated transcription of cotD by sigmaK RNA polymerase in vitro, but a higher level of GerE repressed cotD transcription.\nHere, we show that GerE binds near the sigK transcriptional start site, to act as a repressor.\nWe show that GerE binds to two sites that span the -35 region of the cotD promoter.\nThese results suggest that a rising level of GerE in sporulating cells may first activate cotD transcription from the upstream site then repress transcription as the downstream site becomes occupied.',
#   'T3',
#   'T6',
#   'gerE',
#   'sigmaK',
#   'FALSE'],
#  [],
#  ['LLL_d18',
#   'Most cot genes, and the gerE gene, are transcribed by sigmaK RNA polymerase.\nPreviously, it was shown that the GerE protein inhibits transcription in vitro of the sigK gene encoding sigmaK.\nThese results demonstrate that sigmaK-dependent transcription of gerE initiates a negative feedback loop in which GerE acts as a repressor to limit production of sigmaK.\nA low level of GerE activated transcription of cotD by sigmaK RNA polymerase in vitro, but a higher level of GerE repressed cotD transcription.\nHere, we show that GerE binds near the sigK transcriptional start site, to act as a repressor.\nWe show that GerE binds to two sites that span the -35 region of the cotD promoter.\nThese results suggest that a rising level of GerE in sporulating cells may first activate cotD transcription from the upstream site then repress transcription as the downstream site becomes occupied.',
#   'T3',
#   'T7',
#   'gerE',
#   'GerE',
#   'FALSE'],
#  [],
#  ['LLL_d18',
# ...
#   'T11',
#   'T3',
#   'SpoIIAA-P',
#   'SpoIIE',
#   'FALSE'],
#  [],
#  ['LLL_d14',
#   'The first stage, which involves the phosphatase function of SpoIIE, depends on the cell division protein FtsZ and could correspond to the FtsZ-dependent assembly of SpoIIE into E-rings.\nEvidence based on the use of modified and mutant forms of the phosphatase protein indicates that SpoIIE blocks the capacity of unphosphorylated SpoIIAA to activate sigmaF until formation of the polar septum is completed.\nCell-specific activation of transcription factor sigmaF during sporulation in Bacillus subtilis requires the formation of the polar septum and the activity of a serine phosphatase (SpoIIE) located in the septum.\nThe SpoIIE phosphatase indirectly activates sigmaF by dephosphorylating a protein (SpoIIAA-P) in the pathway that controls the activity of the transcription factor.',
#   'T11',
#   'T2',
#   'SpoIIAA-P',
#   'FtsZ',
#   'FALSE'],
#  [],
#  ['LLL_d14',
#   'The first stage, which involves the phosphatase function of SpoIIE, depends on the cell division protein FtsZ and could correspond to the FtsZ-dependent assembly of SpoIIE into E-rings.\nEvidence based on the use of modified and mutant forms of the phosphatase protein indicates that SpoIIE blocks the capacity of unphosphorylated SpoIIAA to activate sigmaF until formation of the polar septum is completed.\nCell-specific activation of transcription factor sigmaF during sporulation in Bacillus subtilis requires the formation of the polar septum and the activity of a serine phosphatase (SpoIIE) located in the septum.\nThe SpoIIE phosphatase indirectly activates sigmaF by dephosphorylating a protein (SpoIIAA-P) in the pathway that controls the activity of the transcription factor.',
#   'T12',
#   'T8',
#   'sigmaF',
#   'SpoIIE',
#   'FALSE'],
#  [],
#  ['LLL_d14',
#   'The first stage, which involves the phosphatase function of SpoIIE, depends on the cell division protein FtsZ and could correspond to the FtsZ-dependent assembly of SpoIIE into E-rings.\nEvidence based on the use of modified and mutant forms of the phosphatase protein indicates that SpoIIE blocks the capacity of unphosphorylated SpoIIAA to activate sigmaF until formation of the polar septum is completed.\nCell-specific activation of transcription factor sigmaF during sporulation in Bacillus subtilis requires the formation of the polar septum and the activity of a serine phosphatase (SpoIIE) located in the septum.\nThe SpoIIE phosphatase indirectly activates sigmaF by dephosphorylating a protein (SpoIIAA-P) in the pathway that controls the activity of the transcription factor.',
#   'T12',
#   'T9',
#   'sigmaF',
#   'sigmaF',
#   'FALSE'],
#  [],
#  ['LLL_d14',
#   'The first stage, which involves the phosphatase function of SpoIIE, depends on the cell division protein FtsZ and could correspond to the FtsZ-dependent assembly of SpoIIE into E-rings.\nEvidence based on the use of modified and mutant forms of the phosphatase protein indicates that SpoIIE blocks the capacity of unphosphorylated SpoIIAA to activate sigmaF until formation of the polar septum is completed.\nCell-specific activation of transcription factor sigmaF during sporulation in Bacillus subtilis requires the formation of the polar septum and the activity of a serine phosphatase (SpoIIE) located in the septum.\nThe SpoIIE phosphatase indirectly activates sigmaF by dephosphorylating a protein (SpoIIAA-P) in the pathway that controls the activity of the transcription factor.',
#   'T12',
#   'T1',
#   'sigmaF',
#   'FtsZ',
#   'FALSE'],
#  [],
#  ['LLL_d14',
#   'The first stage, which involves the phosphatase function of SpoIIE, depends on the cell division protein FtsZ and could correspond to the FtsZ-dependent assembly of SpoIIE into E-rings.\nEvidence based on the use of modified and mutant forms of the phosphatase protein indicates that SpoIIE blocks the capacity of unphosphorylated SpoIIAA to activate sigmaF until formation of the polar septum is completed.\nCell-specific activation of transcription factor sigmaF during sporulation in Bacillus subtilis requires the formation of the polar septum and the activity of a serine phosphatase (SpoIIE) located in the septum.\nThe SpoIIE phosphatase indirectly activates sigmaF by dephosphorylating a protein (SpoIIAA-P) in the pathway that controls the activity of the transcription factor.',
#   'T12',
#   'T3',
#   'sigmaF',
#   'SpoIIE',
#   'FALSE'],
#  [],
#  ['LLL_d14',
#   'The first stage, which involves the phosphatase function of SpoIIE, depends on the cell division protein FtsZ and could correspond to the FtsZ-dependent assembly of SpoIIE into E-rings.\nEvidence based on the use of modified and mutant forms of the phosphatase protein indicates that SpoIIE blocks the capacity of unphosphorylated SpoIIAA to activate sigmaF until formation of the polar septum is completed.\nCell-specific activation of transcription factor sigmaF during sporulation in Bacillus subtilis requires the formation of the polar septum and the activity of a serine phosphatase (SpoIIE) located in the septum.\nThe SpoIIE phosphatase indirectly activates sigmaF by dephosphorylating a protein (SpoIIAA-P) in the pathway that controls the activity of the transcription factor.',
#   'T12',
#   'T2',
#   'sigmaF',
#   'FtsZ',
#   'FALSE'],
#  [],
#  ['LLL_d14',
#   'The first stage, which involves the phosphatase function of SpoIIE, depends on the cell division protein FtsZ and could correspond to the FtsZ-dependent assembly of SpoIIE into E-rings.\nEvidence based on the use of modified and mutant forms of the phosphatase protein indicates that SpoIIE blocks the capacity of unphosphorylated SpoIIAA to activate sigmaF until formation of the polar septum is completed.\nCell-specific activation of transcription factor sigmaF during sporulation in Bacillus subtilis requires the formation of the polar septum and the activity of a serine phosphatase (SpoIIE) located in the septum.\nThe SpoIIE phosphatase indirectly activates sigmaF by dephosphorylating a protein (SpoIIAA-P) in the pathway that controls the activity of the transcription factor.',
#   'T8',
#   'T9',
#   'SpoIIE',
#   'sigmaF',
#   'TRUE'],
#  [],
#  ['LLL_d14',
#   'The first stage, which involves the phosphatase function of SpoIIE, depends on the cell division protein FtsZ and could correspond to the FtsZ-dependent assembly of SpoIIE into E-rings.\nEvidence based on the use of modified and mutant forms of the phosphatase protein indicates that SpoIIE blocks the capacity of unphosphorylated SpoIIAA to activate sigmaF until formation of the polar septum is completed.\nCell-specific activation of transcription factor sigmaF during sporulation in Bacillus subtilis requires the formation of the polar septum and the activity of a serine phosphatase (SpoIIE) located in the septum.\nThe SpoIIE phosphatase indirectly activates sigmaF by dephosphorylating a protein (SpoIIAA-P) in the pathway that controls the activity of the transcription factor.',
#   'T8',
#   'T1',
#   'SpoIIE',
#   'FtsZ',
#   'FALSE'],
#  [],
#  ['LLL_d14',
#   'The first stage, which involves the phosphatase function of SpoIIE, depends on the cell division protein FtsZ and could correspond to the FtsZ-dependent assembly of SpoIIE into E-rings.\nEvidence based on the use of modified and mutant forms of the phosphatase protein indicates that SpoIIE blocks the capacity of unphosphorylated SpoIIAA to activate sigmaF until formation of the polar septum is completed.\nCell-specific activation of transcription factor sigmaF during sporulation in Bacillus subtilis requires the formation of the polar septum and the activity of a serine phosphatase (SpoIIE) located in the septum.\nThe SpoIIE phosphatase indirectly activates sigmaF by dephosphorylating a protein (SpoIIAA-P) in the pathway that controls the activity of the transcription factor.',
#   'T8',
#   'T3',
#   'SpoIIE',
#   'SpoIIE',
#   'FALSE'],
#  [],
#  ['LLL_d14',
#   'The first stage, which involves the phosphatase function of SpoIIE, depends on the cell division protein FtsZ and could correspond to the FtsZ-dependent assembly of SpoIIE into E-rings.\nEvidence based on the use of modified and mutant forms of the phosphatase protein indicates that SpoIIE blocks the capacity of unphosphorylated SpoIIAA to activate sigmaF until formation of the polar septum is completed.\nCell-specific activation of transcription factor sigmaF during sporulation in Bacillus subtilis requires the formation of the polar septum and the activity of a serine phosphatase (SpoIIE) located in the septum.\nThe SpoIIE phosphatase indirectly activates sigmaF by dephosphorylating a protein (SpoIIAA-P) in the pathway that controls the activity of the transcription factor.',
#   'T8',
#   'T2',
#   'SpoIIE',
#   'FtsZ',
#   'FALSE'],
#  [],
#  ['LLL_d14',
#   'The first stage, which involves the phosphatase function of SpoIIE, depends on the cell division protein FtsZ and could correspond to the FtsZ-dependent assembly of SpoIIE into E-rings.\nEvidence based on the use of modified and mutant forms of the phosphatase protein indicates that SpoIIE blocks the capacity of unphosphorylated SpoIIAA to activate sigmaF until formation of the polar septum is completed.\nCell-specific activation of transcription factor sigmaF during sporulation in Bacillus subtilis requires the formation of the polar septum and the activity of a serine phosphatase (SpoIIE) located in the septum.\nThe SpoIIE phosphatase indirectly activates sigmaF by dephosphorylating a protein (SpoIIAA-P) in the pathway that controls the activity of the transcription factor.',
#   'T9',
#   'T1',
#   'sigmaF',
#   'FtsZ',
#   'FALSE'],
#  [],
#  ['LLL_d14',
#   'The first stage, which involves the phosphatase function of SpoIIE, depends on the cell division protein FtsZ and could correspond to the FtsZ-dependent assembly of SpoIIE into E-rings.\nEvidence based on the use of modified and mutant forms of the phosphatase protein indicates that SpoIIE blocks the capacity of unphosphorylated SpoIIAA to activate sigmaF until formation of the polar septum is completed.\nCell-specific activation of transcription factor sigmaF during sporulation in Bacillus subtilis requires the formation of the polar septum and the activity of a serine phosphatase (SpoIIE) located in the septum.\nThe SpoIIE phosphatase indirectly activates sigmaF by dephosphorylating a protein (SpoIIAA-P) in the pathway that controls the activity of the transcription factor.',
#   'T9',
#   'T3',
#   'sigmaF',
#   'SpoIIE',
#   'FALSE'],
#  [],
#  ['LLL_d14',
#   'The first stage, which involves the phosphatase function of SpoIIE, depends on the cell division protein FtsZ and could correspond to the FtsZ-dependent assembly of SpoIIE into E-rings.\nEvidence based on the use of modified and mutant forms of the phosphatase protein indicates that SpoIIE blocks the capacity of unphosphorylated SpoIIAA to activate sigmaF until formation of the polar septum is completed.\nCell-specific activation of transcription factor sigmaF during sporulation in Bacillus subtilis requires the formation of the polar septum and the activity of a serine phosphatase (SpoIIE) located in the septum.\nThe SpoIIE phosphatase indirectly activates sigmaF by dephosphorylating a protein (SpoIIAA-P) in the pathway that controls the activity of the transcription factor.',
#   'T9',
#   'T2',
#   'sigmaF',
#   'FtsZ',
#   'FALSE'],
#  [],
#  ['LLL_d14',
#   'The first stage, which involves the phosphatase function of SpoIIE, depends on the cell division protein FtsZ and could correspond to the FtsZ-dependent assembly of SpoIIE into E-rings.\nEvidence based on the use of modified and mutant forms of the phosphatase protein indicates that SpoIIE blocks the capacity of unphosphorylated SpoIIAA to activate sigmaF until formation of the polar septum is completed.\nCell-specific activation of transcription factor sigmaF during sporulation in Bacillus subtilis requires the formation of the polar septum and the activity of a serine phosphatase (SpoIIE) located in the septum.\nThe SpoIIE phosphatase indirectly activates sigmaF by dephosphorylating a protein (SpoIIAA-P) in the pathway that controls the activity of the transcription factor.',
#   'T1',
#   'T3',
#   'FtsZ',
#   'SpoIIE',
#   'TRUE'],
#  [],
#  ['LLL_d14',
#   'The first stage, which involves the phosphatase function of SpoIIE, depends on the cell division protein FtsZ and could correspond to the FtsZ-dependent assembly of SpoIIE into E-rings.\nEvidence based on the use of modified and mutant forms of the phosphatase protein indicates that SpoIIE blocks the capacity of unphosphorylated SpoIIAA to activate sigmaF until formation of the polar septum is completed.\nCell-specific activation of transcription factor sigmaF during sporulation in Bacillus subtilis requires the formation of the polar septum and the activity of a serine phosphatase (SpoIIE) located in the septum.\nThe SpoIIE phosphatase indirectly activates sigmaF by dephosphorylating a protein (SpoIIAA-P) in the pathway that controls the activity of the transcription factor.',
#   'T1',
#   'T2',
#   'FtsZ',
#   'FtsZ',
#   'FALSE'],
#  [],
#  ['LLL_d14',
#   'The first stage, which involves the phosphatase function of SpoIIE, depends on the cell division protein FtsZ and could correspond to the FtsZ-dependent assembly of SpoIIE into E-rings.\nEvidence based on the use of modified and mutant forms of the phosphatase protein indicates that SpoIIE blocks the capacity of unphosphorylated SpoIIAA to activate sigmaF until formation of the polar septum is completed.\nCell-specific activation of transcription factor sigmaF during sporulation in Bacillus subtilis requires the formation of the polar septum and the activity of a serine phosphatase (SpoIIE) located in the septum.\nThe SpoIIE phosphatase indirectly activates sigmaF by dephosphorylating a protein (SpoIIAA-P) in the pathway that controls the activity of the transcription factor.',
#   'T3',
#   'T2',
#   'SpoIIE',
#   'FtsZ',
#   'FALSE'],
#  [],
#  ['LLL_d28',
#   'Primer extension experiments and Northern blot analysis show that an active sigmaA-dependent promoter precedes kdgR and transcription is terminated at the putative p-independent terminator downstream of kdgT.',
#   'T1',
#   'T2',
#   'sigmaA',
#   'kdgR',
#   'TRUE'],
#  [],
#  ['LLL_d21',
#   'This stress-induced increase in ykzA expression is absolutely dependent on the alternative sigma factor sigmaB, which controls a large stationary-phase and stress regulon.',
#   'T1',
#   'T2',
#   'sigmaB',
#   'ykzA',
#   'TRUE'],
#  [],
#  ['LLL_d26',
#   'From these results we conclude that ComK negatively regulates degR expression by preventing sigmaD-driven transcription of degR, possibly through interaction with the control region.\nWe have shown previously that the transcription of degR is driven by an alternative sigma factor, sigmaD.',
#   'T6',
#   'T4',
#   'degR',
#   'degR',
#   'FALSE'],
#  [],
#  ['LLL_d26',
#   'From these results we conclude that ComK negatively regulates degR expression by preventing sigmaD-driven transcription of degR, possibly through interaction with the control region.\nWe have shown previously that the transcription of degR is driven by an alternative sigma factor, sigmaD.',
#   'T6',
#   'T5',
#   'degR',
#   'sigmaD',
#   'TRUE'],
#  [],
#  ['LLL_d26',
#   'From these results we conclude that ComK negatively regulates degR expression by preventing sigmaD-driven transcription of degR, possibly through interaction with the control region.\nWe have shown previously that the transcription of degR is driven by an alternative sigma factor, sigmaD.',
#   'T6',
#   'T1',
#   'degR',
#   'ComK',
#   'FALSE'],
#  [],
#  ...]
